# %%
import pandas as pd
import numpy as np

df2008_1 = pd.read_excel('./data/2008/2008_1.xls')
df2008_1 = df2008_1[['날짜','측정소명','PM10']]
df2008_1['날짜'] = df2008_1['날짜'].str[:10]
df2008_1['날짜'] = df2008_1['날짜'].str.replace('-','')
df2008_1.drop(df2008_1.loc[df2008_1['PM10'] == -999].index, inplace = True)

df2008_2 = pd.read_excel('./data/2008/2008_2.xls')
df2008_2 = df2008_2[['날짜','측정소명','PM10']]
df2008_2['날짜'] = df2008_2['날짜'].str[:10]
df2008_2['날짜'] = df2008_2['날짜'].str.replace('-','')
df2008_2.drop(df2008_2.loc[df2008_2['PM10'] == -999].index, inplace = True)

df2008_3 = pd.read_excel('./data/2008/2008_3.xls')
df2008_3 = df2008_3[['날짜','측정소명','PM10']]
df2008_3['날짜'] = df2008_3['날짜'].str[:10]
df2008_3['날짜'] = df2008_3['날짜'].str.replace('-','')
df2008_3.drop(df2008_3.loc[df2008_3['PM10'] == -999].index, inplace = True)

df2008_4 = pd.read_excel('./data/2008/2008_4.xls')
df2008_4 = df2008_4[['날짜','측정소명','PM10']]
df2008_4['날짜'] = df2008_4['날짜'].str[:10]
df2008_4['날짜'] = df2008_4['날짜'].str.replace('-','')
df2008_4.drop(df2008_4.loc[df2008_4['PM10'] == -999].index, inplace = True)

df2008_5 = pd.read_excel('./data/2008/2008_5.xls')
df2008_5 = df2008_5[['날짜','측정소명','PM10']]
df2008_5['날짜'] = df2008_5['날짜'].str[:10]
df2008_5['날짜'] = df2008_5['날짜'].str.replace('-','')
df2008_5.drop(df2008_5.loc[df2008_5['PM10'] == -999].index, inplace = True)

df2008_6 = pd.read_excel('./data/2008/2008_6.xls')
df2008_6 = df2008_6[['날짜','측정소명','PM10']]
df2008_6['날짜'] = df2008_6['날짜'].str[:10]
df2008_6['날짜'] = df2008_6['날짜'].str.replace('-','')
df2008_6.drop(df2008_6.loc[df2008_6['PM10'] == -999].index, inplace = True)

df2008_7 = pd.read_excel('./data/2008/2008_7.xls')
df2008_7 = df2008_7[['날짜','측정소명','PM10']]
df2008_7['날짜'] = df2008_7['날짜'].str[:10]
df2008_7['날짜'] = df2008_7['날짜'].str.replace('-','')
df2008_7.drop(df2008_7.loc[df2008_7['PM10'] == -999].index, inplace = True)

df2008_8 = pd.read_excel('./data/2008/2008_8.xls')
df2008_8 = df2008_8[['날짜','측정소명','PM10']]
df2008_8['날짜'] = df2008_8['날짜'].str[:10]
df2008_8['날짜'] = df2008_8['날짜'].str.replace('-','')
df2008_8.drop(df2008_8.loc[df2008_8['PM10'] == -999].index, inplace = True)

df2008_9 = pd.read_excel('./data/2008/2008_9.xls')
df2008_9 = df2008_9[['날짜','측정소명','PM10']]
df2008_9['날짜'] = df2008_9['날짜'].str[:10]
df2008_9['날짜'] = df2008_9['날짜'].str.replace('-','')
df2008_9.drop(df2008_9.loc[df2008_9['PM10'] == -999].index, inplace = True)

df2008_10 = pd.read_excel('./data/2008/2008_10.xls')
df2008_10 = df2008_10[['날짜','측정소명','PM10']]
df2008_10['날짜'] = df2008_10['날짜'].str[:10]
df2008_10['날짜'] = df2008_10['날짜'].str.replace('-','')
df2008_10.drop(df2008_10.loc[df2008_10['PM10'] == -999].index, inplace = True)

df2008_11 = pd.read_excel('./data/2008/2008_11.xls')
df2008_11 = df2008_11[['날짜','측정소명','PM10']]
df2008_11['날짜'] = df2008_11['날짜'].str[:10]
df2008_11['날짜'] = df2008_11['날짜'].str.replace('-','')
df2008_11.drop(df2008_11.loc[df2008_11['PM10'] == -999].index, inplace = True)

df2008_12 = pd.read_excel('./data/2008/2008_12.xls')
df2008_12 = df2008_12[['날짜','측정소명','PM10']]
df2008_12['날짜'] = df2008_12['날짜'].str[:10]
df2008_12['날짜'] = df2008_12['날짜'].str.replace('-','')
df2008_12.drop(df2008_12.loc[df2008_12['PM10'] == -999].index, inplace = True)

#2008년 1월

#1 - 강남구
df2008_1_GANGNAM = df2008_1[df2008_1['측정소명'] == '강남구']
df2008_1_GANGNAM = df2008_1_GANGNAM.groupby('날짜').mean()
df2008_1_GANGNAM['PM10'] = round(df2008_1_GANGNAM['PM10'], 2)
df2008_1_GANGNAM = df2008_1_GANGNAM.fillna(0)
df2008_1_GANGNAM = df2008_1_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_1_GANGNAM)
#print('\n')

#2 - 강동구
df2008_1_GANGDONG = df2008_1[df2008_1['측정소명'] == '강동구']
df2008_1_GANGDONG = df2008_1_GANGDONG.groupby('날짜').mean()
df2008_1_GANGDONG['PM10'] = round(df2008_1_GANGDONG['PM10'], 2)
df2008_1_GANGDONG = df2008_1_GANGDONG.fillna(0)
df2008_1_GANGDONG = df2008_1_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_1_GANGDONG)
#print('\n')

#3 - 강북구
df2008_1_GANGBUK = df2008_1[df2008_1['측정소명'] == '강북구']
df2008_1_GANGBUK = df2008_1_GANGBUK.groupby('날짜').mean()
df2008_1_GANGBUK['PM10'] = round(df2008_1_GANGBUK['PM10'], 2)
df2008_1_GANGBUK = df2008_1_GANGBUK.fillna(0)
df2008_1_GANGBUK = df2008_1_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_1_GANGBUK)
#print('\n')

#4 - 강서구
df2008_1_GANGSEO = df2008_1[df2008_1['측정소명'] == '강서구']
df2008_1_GANGSEO = df2008_1_GANGSEO.groupby('날짜').mean()
df2008_1_GANGSEO['PM10'] = round(df2008_1_GANGSEO['PM10'], 2)
df2008_1_GANGSEO = df2008_1_GANGSEO.fillna(0)
df2008_1_GANGSEO = df2008_1_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_1_GANGSEO)
#print('\n')

#5 - 관악구
df2008_1_GWANAK = df2008_1[df2008_1['측정소명'] == '관악구']
df2008_1_GWANAK = df2008_1_GWANAK.groupby('날짜').mean()
df2008_1_GWANAK['PM10'] = round(df2008_1_GWANAK['PM10'], 2)
df2008_1_GWANAK = df2008_1_GWANAK.fillna(0)
df2008_1_GWANAK = df2008_1_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_1_GWANAK)
#print('\n')

#6 - 광진구
df2008_1_GWANGJIN = df2008_1[df2008_1['측정소명'] == '광진구']
df2008_1_GWANGJIN = df2008_1_GWANGJIN.groupby('날짜').mean()
df2008_1_GWANGJIN['PM10'] = round(df2008_1_GWANGJIN['PM10'], 2)
df2008_1_GWANGJIN = df2008_1_GWANGJIN.fillna(0)
df2008_1_GWANGJIN = df2008_1_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_1_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_1_GURO = df2008_1[df2008_1['측정소명'] == '구로구']
df2008_1_GURO = df2008_1_GURO.groupby('날짜').mean()
df2008_1_GURO['PM10'] = round(df2008_1_GURO['PM10'], 2)
df2008_1_GURO = df2008_1_GURO.fillna(0)
df2008_1_GURO = df2008_1_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_1_GURO)
#print('\n')

#8 - 금천구
df2008_1_GEUMCHEON = df2008_1[df2008_1['측정소명'] == '금천구']
df2008_1_GEUMCHEON = df2008_1_GEUMCHEON.groupby('날짜').mean()
df2008_1_GEUMCHEON['PM10'] = round(df2008_1_GEUMCHEON['PM10'], 2)
df2008_1_GEUMCHEON = df2008_1_GEUMCHEON.fillna(0)
df2008_1_GEUMCHEON = df2008_1_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_1_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_1_NOWON = df2008_1[df2008_1['측정소명'] == '노원구']
df2008_1_NOWON = df2008_1_NOWON.groupby('날짜').mean()
df2008_1_NOWON['PM10'] = round(df2008_1_NOWON['PM10'], 2)
df2008_1_NOWON = df2008_1_NOWON.fillna(0)
df2008_1_NOWON = df2008_1_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_1_NOWON)
#print('\n')

#10 - 도봉구
df2008_1_DOBONG = df2008_1[df2008_1['측정소명'] == '도봉구']
df2008_1_DOBONG = df2008_1_DOBONG.groupby('날짜').mean()
df2008_1_DOBONG['PM10'] = round(df2008_1_DOBONG['PM10'], 2)
df2008_1_DOBONG = df2008_1_DOBONG.fillna(0)
df2008_1_DOBONG = df2008_1_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_1_DOBONG)
#print('\n')

#11 - 동대문구
df2008_1_DONGDAEMUN = df2008_1[df2008_1['측정소명'] == '동대문구']
df2008_1_DONGDAEMUN = df2008_1_DONGDAEMUN.groupby('날짜').mean()
df2008_1_DONGDAEMUN['PM10'] = round(df2008_1_DONGDAEMUN['PM10'], 2)
df2008_1_DONGDAEMUN = df2008_1_DONGDAEMUN.fillna(0)
df2008_1_DONGDAEMUN = df2008_1_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_1_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_1_DONGJAK = df2008_1[df2008_1['측정소명'] == '동작구']
df2008_1_DONGJAK = df2008_1_DONGJAK.groupby('날짜').mean()
df2008_1_DONGJAK['PM10'] = round(df2008_1_DONGJAK['PM10'], 2)
df2008_1_DONGJAK = df2008_1_DONGJAK.fillna(0)
df2008_1_DONGJAK = df2008_1_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_1_DONGJAK)
#print('\n')

#13 - 마포구
df2008_1_MAPO = df2008_1[df2008_1['측정소명'] == '마포구']
df2008_1_MAPO = df2008_1_MAPO.groupby('날짜').mean()
df2008_1_MAPO['PM10'] = round(df2008_1_MAPO['PM10'], 2)
df2008_1_MAPO = df2008_1_MAPO.fillna(0)
df2008_1_MAPO = df2008_1_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_1_MAPO)
#print('\n')

#14 - 서대문구
df2008_1_SEODAEMUN = df2008_1[df2008_1['측정소명'] == '서대문구']
df2008_1_SEODAEMUN = df2008_1_SEODAEMUN.groupby('날짜').mean()
df2008_1_SEODAEMUN['PM10'] = round(df2008_1_SEODAEMUN['PM10'], 2)
df2008_1_SEODAEMUN = df2008_1_SEODAEMUN.fillna(0)
df2008_1_SEODAEMUN = df2008_1_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_1_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_1_SEOCHO = df2008_1[df2008_1['측정소명'] == '서초구']
df2008_1_SEOCHO = df2008_1_SEOCHO.groupby('날짜').mean()
df2008_1_SEOCHO['PM10'] = round(df2008_1_SEOCHO['PM10'], 2)
df2008_1_SEOCHO = df2008_1_SEOCHO.fillna(0)
df2008_1_SEOCHO = df2008_1_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_1_SEOCHO)
#print('\n')

#16 - 성동구
df2008_1_SEONGDONG = df2008_1[df2008_1['측정소명'] == '성동구']
df2008_1_SEONGDONG = df2008_1_SEONGDONG.groupby('날짜').mean()
df2008_1_SEONGDONG['PM10'] = round(df2008_1_SEONGDONG['PM10'], 2)
df2008_1_SEONGDONG = df2008_1_SEONGDONG.fillna(0)
df2008_1_SEONGDONG = df2008_1_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_1_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_1_SEONGBUK = df2008_1[df2008_1['측정소명'] == '성북구']
df2008_1_SEONGBUK = df2008_1_SEONGBUK.groupby('날짜').mean()
df2008_1_SEONGBUK['PM10'] = round(df2008_1_SEONGBUK['PM10'], 2)
df2008_1_SEONGBUK = df2008_1_SEONGBUK.fillna(0)
df2008_1_SEONGBUK = df2008_1_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_1_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_1_SONGPA = df2008_1[df2008_1['측정소명'] == '송파구']
df2008_1_SONGPA = df2008_1_SONGPA.groupby('날짜').mean()
df2008_1_SONGPA['PM10'] = round(df2008_1_SONGPA['PM10'], 2)
df2008_1_SONGPA = df2008_1_SONGPA.fillna(0)
df2008_1_SONGPA = df2008_1_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_1_SONGPA)
#print('\n')

#19 - 양천구
df2008_1_YANGCHEON = df2008_1[df2008_1['측정소명'] == '양천구']
df2008_1_YANGCHEON = df2008_1_YANGCHEON.groupby('날짜').mean()
df2008_1_YANGCHEON['PM10'] = round(df2008_1_YANGCHEON['PM10'], 2)
df2008_1_YANGCHEON = df2008_1_YANGCHEON.fillna(0)
df2008_1_YANGCHEON = df2008_1_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_1_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_1_YEONGDEUNGPO = df2008_1[df2008_1['측정소명'] == '영등포구']
df2008_1_YEONGDEUNGPO = df2008_1_YEONGDEUNGPO.groupby('날짜').mean()
df2008_1_YEONGDEUNGPO['PM10'] = round(df2008_1_YEONGDEUNGPO['PM10'], 2)
df2008_1_YEONGDEUNGPO = df2008_1_YEONGDEUNGPO.fillna(0)
df2008_1_YEONGDEUNGPO = df2008_1_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_1_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_1_YONGSAN = df2008_1[df2008_1['측정소명'] == '용산구']
df2008_1_YONGSAN = df2008_1_YONGSAN.groupby('날짜').mean()
df2008_1_YONGSAN['PM10'] = round(df2008_1_YONGSAN['PM10'], 2)
df2008_1_YONGSAN = df2008_1_YONGSAN.fillna(0)
df2008_1_YONGSAN = df2008_1_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_1_YONGSAN)
#print('\n')

#22 - 은평구
df2008_1_EUNPYEONG = df2008_1[df2008_1['측정소명'] == '은평구']
df2008_1_EUNPYEONG = df2008_1_EUNPYEONG.groupby('날짜').mean()
df2008_1_EUNPYEONG['PM10'] = round(df2008_1_EUNPYEONG['PM10'], 2)
df2008_1_EUNPYEONG = df2008_1_EUNPYEONG.fillna(0)
df2008_1_EUNPYEONG = df2008_1_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_1_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_1_JONGNO = df2008_1[df2008_1['측정소명'] == '종로구']
df2008_1_JONGNO = df2008_1_JONGNO.groupby('날짜').mean()
df2008_1_JONGNO['PM10'] = round(df2008_1_JONGNO['PM10'], 2)
df2008_1_JONGNO = df2008_1_JONGNO.fillna(0)
df2008_1_JONGNO = df2008_1_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_1_JONGNO)
#print('\n')

#24 - 중구
df2008_1_JUNG = df2008_1[df2008_1['측정소명'] == '중구']
df2008_1_JUNG = df2008_1_JUNG.groupby('날짜').mean()
df2008_1_JUNG['PM10'] = round(df2008_1_JUNG['PM10'], 2)
df2008_1_JUNG = df2008_1_JUNG.fillna(0)
df2008_1_JUNG = df2008_1_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_1_JUNG)
#print('\n')

#25 - 중랑구
df2008_1_JUNGNANG = df2008_1[df2008_1['측정소명'] == '중랑구']
df2008_1_JUNGNANG = df2008_1_JUNGNANG.groupby('날짜').mean()
df2008_1_JUNGNANG['PM10'] = round(df2008_1_JUNGNANG['PM10'], 2)
df2008_1_JUNGNANG = df2008_1_JUNGNANG.fillna(0)
df2008_1_JUNGNANG = df2008_1_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_1_JUNGNANG)

#======================
my2008_1 = pd.concat([df2008_1_GANGNAM, df2008_1_GANGDONG, df2008_1_GANGBUK, df2008_1_GANGSEO,
                      df2008_1_GWANAK, df2008_1_GWANGJIN, df2008_1_GURO, df2008_1_GEUMCHEON,
                      df2008_1_NOWON, df2008_1_DOBONG, df2008_1_DONGDAEMUN, df2008_1_DONGJAK,
                      df2008_1_MAPO, df2008_1_SEODAEMUN, df2008_1_SEOCHO, df2008_1_SEONGDONG,
                      df2008_1_SEONGBUK, df2008_1_SONGPA, df2008_1_YANGCHEON, df2008_1_YEONGDEUNGPO,
                      df2008_1_YONGSAN, df2008_1_EUNPYEONG, df2008_1_JONGNO, df2008_1_JUNG,
                      df2008_1_JUNGNANG], axis = 1)

#2008년 2월

#1 - 강남구
df2008_2_GANGNAM = df2008_2[df2008_2['측정소명'] == '강남구']
df2008_2_GANGNAM = df2008_2_GANGNAM.groupby('날짜').mean()
df2008_2_GANGNAM['PM10'] = round(df2008_2_GANGNAM['PM10'], 2)
df2008_2_GANGNAM = df2008_2_GANGNAM.fillna(0)
df2008_2_GANGNAM = df2008_2_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_2_GANGNAM)
#print('\n')

#2 - 강동구
df2008_2_GANGDONG = df2008_2[df2008_2['측정소명'] == '강동구']
df2008_2_GANGDONG = df2008_2_GANGDONG.groupby('날짜').mean()
df2008_2_GANGDONG['PM10'] = round(df2008_2_GANGDONG['PM10'], 2)
df2008_2_GANGDONG = df2008_2_GANGDONG.fillna(0)
df2008_2_GANGDONG = df2008_2_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_2_GANGDONG)
#print('\n')

#3 - 강북구
df2008_2_GANGBUK = df2008_2[df2008_2['측정소명'] == '강북구']
df2008_2_GANGBUK = df2008_2_GANGBUK.groupby('날짜').mean()
df2008_2_GANGBUK['PM10'] = round(df2008_2_GANGBUK['PM10'], 2)
df2008_2_GANGBUK = df2008_2_GANGBUK.fillna(0)
df2008_2_GANGBUK = df2008_2_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_2_GANGBUK)
#print('\n')

#4 - 강서구
df2008_2_GANGSEO = df2008_2[df2008_2['측정소명'] == '강서구']
df2008_2_GANGSEO = df2008_2_GANGSEO.groupby('날짜').mean()
df2008_2_GANGSEO['PM10'] = round(df2008_2_GANGSEO['PM10'], 2)
df2008_2_GANGSEO = df2008_2_GANGSEO.fillna(0)
df2008_2_GANGSEO = df2008_2_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_2_GANGSEO)
#print('\n')

#5 - 관악구
df2008_2_GWANAK = df2008_2[df2008_2['측정소명'] == '관악구']
df2008_2_GWANAK = df2008_2_GWANAK.groupby('날짜').mean()
df2008_2_GWANAK['PM10'] = round(df2008_2_GWANAK['PM10'], 2)
df2008_2_GWANAK = df2008_2_GWANAK.fillna(0)
df2008_2_GWANAK = df2008_2_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_2_GWANAK)
#print('\n')

#6 - 광진구
df2008_2_GWANGJIN = df2008_2[df2008_2['측정소명'] == '광진구']
df2008_2_GWANGJIN = df2008_2_GWANGJIN.groupby('날짜').mean()
df2008_2_GWANGJIN['PM10'] = round(df2008_2_GWANGJIN['PM10'], 2)
df2008_2_GWANGJIN = df2008_2_GWANGJIN.fillna(0)
df2008_2_GWANGJIN = df2008_2_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_2_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_2_GURO = df2008_2[df2008_2['측정소명'] == '구로구']
df2008_2_GURO = df2008_2_GURO.groupby('날짜').mean()
df2008_2_GURO['PM10'] = round(df2008_2_GURO['PM10'], 2)
df2008_2_GURO = df2008_2_GURO.fillna(0)
df2008_2_GURO = df2008_2_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_2_GURO)
#print('\n')

#8 - 금천구
df2008_2_GEUMCHEON = df2008_2[df2008_2['측정소명'] == '금천구']
df2008_2_GEUMCHEON = df2008_2_GEUMCHEON.groupby('날짜').mean()
df2008_2_GEUMCHEON['PM10'] = round(df2008_2_GEUMCHEON['PM10'], 2)
df2008_2_GEUMCHEON = df2008_2_GEUMCHEON.fillna(0)
df2008_2_GEUMCHEON = df2008_2_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_2_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_2_NOWON = df2008_2[df2008_2['측정소명'] == '노원구']
df2008_2_NOWON = df2008_2_NOWON.groupby('날짜').mean()
df2008_2_NOWON['PM10'] = round(df2008_2_NOWON['PM10'], 2)
df2008_2_NOWON = df2008_2_NOWON.fillna(0)
df2008_2_NOWON = df2008_2_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_2_NOWON)
#print('\n')

#10 - 도봉구
df2008_2_DOBONG = df2008_2[df2008_2['측정소명'] == '도봉구']
df2008_2_DOBONG = df2008_2_DOBONG.groupby('날짜').mean()
df2008_2_DOBONG['PM10'] = round(df2008_2_DOBONG['PM10'], 2)
df2008_2_DOBONG = df2008_2_DOBONG.fillna(0)
df2008_2_DOBONG = df2008_2_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_2_DOBONG)
#print('\n')

#11 - 동대문구
df2008_2_DONGDAEMUN = df2008_2[df2008_2['측정소명'] == '동대문구']
df2008_2_DONGDAEMUN = df2008_2_DONGDAEMUN.groupby('날짜').mean()
df2008_2_DONGDAEMUN['PM10'] = round(df2008_2_DONGDAEMUN['PM10'], 2)
df2008_2_DONGDAEMUN = df2008_2_DONGDAEMUN.fillna(0)
df2008_2_DONGDAEMUN = df2008_2_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_2_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_2_DONGJAK = df2008_2[df2008_2['측정소명'] == '동작구']
df2008_2_DONGJAK = df2008_2_DONGJAK.groupby('날짜').mean()
df2008_2_DONGJAK['PM10'] = round(df2008_2_DONGJAK['PM10'], 2)
df2008_2_DONGJAK = df2008_2_DONGJAK.fillna(0)
df2008_2_DONGJAK = df2008_2_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_2_DONGJAK)
#print('\n')

#13 - 마포구
df2008_2_MAPO = df2008_2[df2008_2['측정소명'] == '마포구']
df2008_2_MAPO = df2008_2_MAPO.groupby('날짜').mean()
df2008_2_MAPO['PM10'] = round(df2008_2_MAPO['PM10'], 2)
df2008_2_MAPO = df2008_2_MAPO.fillna(0)
df2008_2_MAPO = df2008_2_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_2_MAPO)
#print('\n')

#14 - 서대문구
df2008_2_SEODAEMUN = df2008_2[df2008_2['측정소명'] == '서대문구']
df2008_2_SEODAEMUN = df2008_2_SEODAEMUN.groupby('날짜').mean()
df2008_2_SEODAEMUN['PM10'] = round(df2008_2_SEODAEMUN['PM10'], 2)
df2008_2_SEODAEMUN = df2008_2_SEODAEMUN.fillna(0)
df2008_2_SEODAEMUN = df2008_2_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_2_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_2_SEOCHO = df2008_2[df2008_2['측정소명'] == '서초구']
df2008_2_SEOCHO = df2008_2_SEOCHO.groupby('날짜').mean()
df2008_2_SEOCHO['PM10'] = round(df2008_2_SEOCHO['PM10'], 2)
df2008_2_SEOCHO = df2008_2_SEOCHO.fillna(0)
df2008_2_SEOCHO = df2008_2_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_2_SEOCHO)
#print('\n')

#16 - 성동구
df2008_2_SEONGDONG = df2008_2[df2008_2['측정소명'] == '성동구']
df2008_2_SEONGDONG = df2008_2_SEONGDONG.groupby('날짜').mean()
df2008_2_SEONGDONG['PM10'] = round(df2008_2_SEONGDONG['PM10'], 2)
df2008_2_SEONGDONG = df2008_2_SEONGDONG.fillna(0)
df2008_2_SEONGDONG = df2008_2_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_2_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_2_SEONGBUK = df2008_2[df2008_2['측정소명'] == '성북구']
df2008_2_SEONGBUK = df2008_2_SEONGBUK.groupby('날짜').mean()
df2008_2_SEONGBUK['PM10'] = round(df2008_2_SEONGBUK['PM10'], 2)
df2008_2_SEONGBUK = df2008_2_SEONGBUK.fillna(0)
df2008_2_SEONGBUK = df2008_2_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_2_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_2_SONGPA = df2008_2[df2008_2['측정소명'] == '송파구']
df2008_2_SONGPA = df2008_2_SONGPA.groupby('날짜').mean()
df2008_2_SONGPA['PM10'] = round(df2008_2_SONGPA['PM10'], 2)
df2008_2_SONGPA = df2008_2_SONGPA.fillna(0)
df2008_2_SONGPA = df2008_2_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_2_SONGPA)
#print('\n')

#19 - 양천구
df2008_2_YANGCHEON = df2008_2[df2008_2['측정소명'] == '양천구']
df2008_2_YANGCHEON = df2008_2_YANGCHEON.groupby('날짜').mean()
df2008_2_YANGCHEON['PM10'] = round(df2008_2_YANGCHEON['PM10'], 2)
df2008_2_YANGCHEON = df2008_2_YANGCHEON.fillna(0)
df2008_2_YANGCHEON = df2008_2_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_2_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_2_YEONGDEUNGPO = df2008_2[df2008_2['측정소명'] == '영등포구']
df2008_2_YEONGDEUNGPO = df2008_2_YEONGDEUNGPO.groupby('날짜').mean()
df2008_2_YEONGDEUNGPO['PM10'] = round(df2008_2_YEONGDEUNGPO['PM10'], 2)
df2008_2_YEONGDEUNGPO = df2008_2_YEONGDEUNGPO.fillna(0)
df2008_2_YEONGDEUNGPO = df2008_2_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_2_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_2_YONGSAN = df2008_2[df2008_2['측정소명'] == '용산구']
df2008_2_YONGSAN = df2008_2_YONGSAN.groupby('날짜').mean()
df2008_2_YONGSAN['PM10'] = round(df2008_2_YONGSAN['PM10'], 2)
df2008_2_YONGSAN = df2008_2_YONGSAN.fillna(0)
df2008_2_YONGSAN = df2008_2_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_2_YONGSAN)
#print('\n')

#22 - 은평구
df2008_2_EUNPYEONG = df2008_2[df2008_2['측정소명'] == '은평구']
df2008_2_EUNPYEONG = df2008_2_EUNPYEONG.groupby('날짜').mean()
df2008_2_EUNPYEONG['PM10'] = round(df2008_2_EUNPYEONG['PM10'], 2)
df2008_2_EUNPYEONG = df2008_2_EUNPYEONG.fillna(0)
df2008_2_EUNPYEONG = df2008_2_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_2_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_2_JONGNO = df2008_2[df2008_2['측정소명'] == '종로구']
df2008_2_JONGNO = df2008_2_JONGNO.groupby('날짜').mean()
df2008_2_JONGNO['PM10'] = round(df2008_2_JONGNO['PM10'], 2)
df2008_2_JONGNO = df2008_2_JONGNO.fillna(0)
df2008_2_JONGNO = df2008_2_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_2_JONGNO)
#print('\n')

#24 - 중구
df2008_2_JUNG = df2008_2[df2008_2['측정소명'] == '중구']
df2008_2_JUNG = df2008_2_JUNG.groupby('날짜').mean()
df2008_2_JUNG['PM10'] = round(df2008_2_JUNG['PM10'], 2)
df2008_2_JUNG = df2008_2_JUNG.fillna(0)
df2008_2_JUNG = df2008_2_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_2_JUNG)
#print('\n')

#25 - 중랑구
df2008_2_JUNGNANG = df2008_2[df2008_2['측정소명'] == '중랑구']
df2008_2_JUNGNANG = df2008_2_JUNGNANG.groupby('날짜').mean()
df2008_2_JUNGNANG['PM10'] = round(df2008_2_JUNGNANG['PM10'], 2)
df2008_2_JUNGNANG = df2008_2_JUNGNANG.fillna(0)
df2008_2_JUNGNANG = df2008_2_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_2_JUNGNANG)

#======================
my2008_2 = pd.concat([df2008_2_GANGNAM, df2008_2_GANGDONG, df2008_2_GANGBUK, df2008_2_GANGSEO,
                      df2008_2_GWANAK, df2008_2_GWANGJIN, df2008_2_GURO, df2008_2_GEUMCHEON,
                      df2008_2_NOWON, df2008_2_DOBONG, df2008_2_DONGDAEMUN, df2008_2_DONGJAK,
                      df2008_2_MAPO, df2008_2_SEODAEMUN, df2008_2_SEOCHO, df2008_2_SEONGDONG,
                      df2008_2_SEONGBUK, df2008_2_SONGPA, df2008_2_YANGCHEON, df2008_2_YEONGDEUNGPO,
                      df2008_2_YONGSAN, df2008_2_EUNPYEONG, df2008_2_JONGNO, df2008_2_JUNG,
                      df2008_2_JUNGNANG], axis = 1)
#2008년 3월

#1 - 강남구
df2008_3_GANGNAM = df2008_3[df2008_3['측정소명'] == '강남구']
df2008_3_GANGNAM = df2008_3_GANGNAM.groupby('날짜').mean()
df2008_3_GANGNAM['PM10'] = round(df2008_3_GANGNAM['PM10'], 2)
df2008_3_GANGNAM = df2008_3_GANGNAM.fillna(0)
df2008_3_GANGNAM = df2008_3_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_3_GANGNAM)
#print('\n')

#2 - 강동구
df2008_3_GANGDONG = df2008_3[df2008_3['측정소명'] == '강동구']
df2008_3_GANGDONG = df2008_3_GANGDONG.groupby('날짜').mean()
df2008_3_GANGDONG['PM10'] = round(df2008_3_GANGDONG['PM10'], 2)
df2008_3_GANGDONG = df2008_3_GANGDONG.fillna(0)
df2008_3_GANGDONG = df2008_3_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_3_GANGDONG)
#print('\n')

#3 - 강북구
df2008_3_GANGBUK = df2008_3[df2008_3['측정소명'] == '강북구']
df2008_3_GANGBUK = df2008_3_GANGBUK.groupby('날짜').mean()
df2008_3_GANGBUK['PM10'] = round(df2008_3_GANGBUK['PM10'], 2)
df2008_3_GANGBUK = df2008_3_GANGBUK.fillna(0)
df2008_3_GANGBUK = df2008_3_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_3_GANGBUK)
#print('\n')

#4 - 강서구
df2008_3_GANGSEO = df2008_3[df2008_3['측정소명'] == '강서구']
df2008_3_GANGSEO = df2008_3_GANGSEO.groupby('날짜').mean()
df2008_3_GANGSEO['PM10'] = round(df2008_3_GANGSEO['PM10'], 2)
df2008_3_GANGSEO = df2008_3_GANGSEO.fillna(0)
df2008_3_GANGSEO = df2008_3_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_3_GANGSEO)
#print('\n')

#5 - 관악구
df2008_3_GWANAK = df2008_3[df2008_3['측정소명'] == '관악구']
df2008_3_GWANAK = df2008_3_GWANAK.groupby('날짜').mean()
df2008_3_GWANAK['PM10'] = round(df2008_3_GWANAK['PM10'], 2)
df2008_3_GWANAK = df2008_3_GWANAK.fillna(0)
df2008_3_GWANAK = df2008_3_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_3_GWANAK)
#print('\n')

#6 - 광진구
df2008_3_GWANGJIN = df2008_3[df2008_3['측정소명'] == '광진구']
df2008_3_GWANGJIN = df2008_3_GWANGJIN.groupby('날짜').mean()
df2008_3_GWANGJIN['PM10'] = round(df2008_3_GWANGJIN['PM10'], 2)
df2008_3_GWANGJIN = df2008_3_GWANGJIN.fillna(0)
df2008_3_GWANGJIN = df2008_3_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_3_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_3_GURO = df2008_3[df2008_3['측정소명'] == '구로구']
df2008_3_GURO = df2008_3_GURO.groupby('날짜').mean()
df2008_3_GURO['PM10'] = round(df2008_3_GURO['PM10'], 2)
df2008_3_GURO = df2008_3_GURO.fillna(0)
df2008_3_GURO = df2008_3_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_3_GURO)
#print('\n')

#8 - 금천구
df2008_3_GEUMCHEON = df2008_3[df2008_3['측정소명'] == '금천구']
df2008_3_GEUMCHEON = df2008_3_GEUMCHEON.groupby('날짜').mean()
df2008_3_GEUMCHEON['PM10'] = round(df2008_3_GEUMCHEON['PM10'], 2)
df2008_3_GEUMCHEON = df2008_3_GEUMCHEON.fillna(0)
df2008_3_GEUMCHEON = df2008_3_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_3_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_3_NOWON = df2008_3[df2008_3['측정소명'] == '노원구']
df2008_3_NOWON = df2008_3_NOWON.groupby('날짜').mean()
df2008_3_NOWON['PM10'] = round(df2008_3_NOWON['PM10'], 2)
df2008_3_NOWON = df2008_3_NOWON.fillna(0)
df2008_3_NOWON = df2008_3_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_3_NOWON)
#print('\n')

#10 - 도봉구
df2008_3_DOBONG = df2008_3[df2008_3['측정소명'] == '도봉구']
df2008_3_DOBONG = df2008_3_DOBONG.groupby('날짜').mean()
df2008_3_DOBONG['PM10'] = round(df2008_3_DOBONG['PM10'], 2)
df2008_3_DOBONG = df2008_3_DOBONG.fillna(0)
df2008_3_DOBONG = df2008_3_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_3_DOBONG)
#print('\n')

#11 - 동대문구
df2008_3_DONGDAEMUN = df2008_3[df2008_3['측정소명'] == '동대문구']
df2008_3_DONGDAEMUN = df2008_3_DONGDAEMUN.groupby('날짜').mean()
df2008_3_DONGDAEMUN['PM10'] = round(df2008_3_DONGDAEMUN['PM10'], 2)
df2008_3_DONGDAEMUN = df2008_3_DONGDAEMUN.fillna(0)
df2008_3_DONGDAEMUN = df2008_3_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_3_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_3_DONGJAK = df2008_3[df2008_3['측정소명'] == '동작구']
df2008_3_DONGJAK = df2008_3_DONGJAK.groupby('날짜').mean()
df2008_3_DONGJAK['PM10'] = round(df2008_3_DONGJAK['PM10'], 2)
df2008_3_DONGJAK = df2008_3_DONGJAK.fillna(0)
df2008_3_DONGJAK = df2008_3_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_3_DONGJAK)
#print('\n')

#13 - 마포구
df2008_3_MAPO = df2008_3[df2008_3['측정소명'] == '마포구']
df2008_3_MAPO = df2008_3_MAPO.groupby('날짜').mean()
df2008_3_MAPO['PM10'] = round(df2008_3_MAPO['PM10'], 2)
df2008_3_MAPO = df2008_3_MAPO.fillna(0)
df2008_3_MAPO = df2008_3_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_3_MAPO)
#print('\n')

#14 - 서대문구
df2008_3_SEODAEMUN = df2008_3[df2008_3['측정소명'] == '서대문구']
df2008_3_SEODAEMUN = df2008_3_SEODAEMUN.groupby('날짜').mean()
df2008_3_SEODAEMUN['PM10'] = round(df2008_3_SEODAEMUN['PM10'], 2)
df2008_3_SEODAEMUN = df2008_3_SEODAEMUN.fillna(0)
df2008_3_SEODAEMUN = df2008_3_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_3_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_3_SEOCHO = df2008_3[df2008_3['측정소명'] == '서초구']
df2008_3_SEOCHO = df2008_3_SEOCHO.groupby('날짜').mean()
df2008_3_SEOCHO['PM10'] = round(df2008_3_SEOCHO['PM10'], 2)
df2008_3_SEOCHO = df2008_3_SEOCHO.fillna(0)
df2008_3_SEOCHO = df2008_3_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_3_SEOCHO)
#print('\n')

#16 - 성동구
df2008_3_SEONGDONG = df2008_3[df2008_3['측정소명'] == '성동구']
df2008_3_SEONGDONG = df2008_3_SEONGDONG.groupby('날짜').mean()
df2008_3_SEONGDONG['PM10'] = round(df2008_3_SEONGDONG['PM10'], 2)
df2008_3_SEONGDONG = df2008_3_SEONGDONG.fillna(0)
df2008_3_SEONGDONG = df2008_3_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_3_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_3_SEONGBUK = df2008_3[df2008_3['측정소명'] == '성북구']
df2008_3_SEONGBUK = df2008_3_SEONGBUK.groupby('날짜').mean()
df2008_3_SEONGBUK['PM10'] = round(df2008_3_SEONGBUK['PM10'], 2)
df2008_3_SEONGBUK = df2008_3_SEONGBUK.fillna(0)
df2008_3_SEONGBUK = df2008_3_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_3_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_3_SONGPA = df2008_3[df2008_3['측정소명'] == '송파구']
df2008_3_SONGPA = df2008_3_SONGPA.groupby('날짜').mean()
df2008_3_SONGPA['PM10'] = round(df2008_3_SONGPA['PM10'], 2)
df2008_3_SONGPA = df2008_3_SONGPA.fillna(0)
df2008_3_SONGPA = df2008_3_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_3_SONGPA)
#print('\n')

#19 - 양천구
df2008_3_YANGCHEON = df2008_3[df2008_3['측정소명'] == '양천구']
df2008_3_YANGCHEON = df2008_3_YANGCHEON.groupby('날짜').mean()
df2008_3_YANGCHEON['PM10'] = round(df2008_3_YANGCHEON['PM10'], 2)
df2008_3_YANGCHEON = df2008_3_YANGCHEON.fillna(0)
df2008_3_YANGCHEON = df2008_3_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_3_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_3_YEONGDEUNGPO = df2008_3[df2008_3['측정소명'] == '영등포구']
df2008_3_YEONGDEUNGPO = df2008_3_YEONGDEUNGPO.groupby('날짜').mean()
df2008_3_YEONGDEUNGPO['PM10'] = round(df2008_3_YEONGDEUNGPO['PM10'], 2)
df2008_3_YEONGDEUNGPO = df2008_3_YEONGDEUNGPO.fillna(0)
df2008_3_YEONGDEUNGPO = df2008_3_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_3_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_3_YONGSAN = df2008_3[df2008_3['측정소명'] == '용산구']
df2008_3_YONGSAN = df2008_3_YONGSAN.groupby('날짜').mean()
df2008_3_YONGSAN['PM10'] = round(df2008_3_YONGSAN['PM10'], 2)
df2008_3_YONGSAN = df2008_3_YONGSAN.fillna(0)
df2008_3_YONGSAN = df2008_3_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_3_YONGSAN)
#print('\n')

#22 - 은평구
df2008_3_EUNPYEONG = df2008_3[df2008_3['측정소명'] == '은평구']
df2008_3_EUNPYEONG = df2008_3_EUNPYEONG.groupby('날짜').mean()
df2008_3_EUNPYEONG['PM10'] = round(df2008_3_EUNPYEONG['PM10'], 2)
df2008_3_EUNPYEONG = df2008_3_EUNPYEONG.fillna(0)
df2008_3_EUNPYEONG = df2008_3_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_3_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_3_JONGNO = df2008_3[df2008_3['측정소명'] == '종로구']
df2008_3_JONGNO = df2008_3_JONGNO.groupby('날짜').mean()
df2008_3_JONGNO['PM10'] = round(df2008_3_JONGNO['PM10'], 2)
df2008_3_JONGNO = df2008_3_JONGNO.fillna(0)
df2008_3_JONGNO = df2008_3_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_3_JONGNO)
#print('\n')

#24 - 중구
df2008_3_JUNG = df2008_3[df2008_3['측정소명'] == '중구']
df2008_3_JUNG = df2008_3_JUNG.groupby('날짜').mean()
df2008_3_JUNG['PM10'] = round(df2008_3_JUNG['PM10'], 2)
df2008_3_JUNG = df2008_3_JUNG.fillna(0)
df2008_3_JUNG = df2008_3_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_3_JUNG)
#print('\n')

#25 - 중랑구
df2008_3_JUNGNANG = df2008_3[df2008_3['측정소명'] == '중랑구']
df2008_3_JUNGNANG = df2008_3_JUNGNANG.groupby('날짜').mean()
df2008_3_JUNGNANG['PM10'] = round(df2008_3_JUNGNANG['PM10'], 2)
df2008_3_JUNGNANG = df2008_3_JUNGNANG.fillna(0)
df2008_3_JUNGNANG = df2008_3_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_3_JUNGNANG)

#======================
my2008_3 = pd.concat([df2008_3_GANGNAM, df2008_3_GANGDONG, df2008_3_GANGBUK, df2008_3_GANGSEO,
                      df2008_3_GWANAK, df2008_3_GWANGJIN, df2008_3_GURO, df2008_3_GEUMCHEON,
                      df2008_3_NOWON, df2008_3_DOBONG, df2008_3_DONGDAEMUN, df2008_3_DONGJAK,
                      df2008_3_MAPO, df2008_3_SEODAEMUN, df2008_3_SEOCHO, df2008_3_SEONGDONG,
                      df2008_3_SEONGBUK, df2008_3_SONGPA, df2008_3_YANGCHEON, df2008_3_YEONGDEUNGPO,
                      df2008_3_YONGSAN, df2008_3_EUNPYEONG, df2008_3_JONGNO, df2008_3_JUNG,
                      df2008_3_JUNGNANG], axis = 1)
#2008년 4월

#1 - 강남구
df2008_4_GANGNAM = df2008_4[df2008_4['측정소명'] == '강남구']
df2008_4_GANGNAM = df2008_4_GANGNAM.groupby('날짜').mean()
df2008_4_GANGNAM['PM10'] = round(df2008_4_GANGNAM['PM10'], 2)
df2008_4_GANGNAM = df2008_4_GANGNAM.fillna(0)
df2008_4_GANGNAM = df2008_4_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_4_GANGNAM)
#print('\n')

#2 - 강동구
df2008_4_GANGDONG = df2008_4[df2008_4['측정소명'] == '강동구']
df2008_4_GANGDONG = df2008_4_GANGDONG.groupby('날짜').mean()
df2008_4_GANGDONG['PM10'] = round(df2008_4_GANGDONG['PM10'], 2)
df2008_4_GANGDONG = df2008_4_GANGDONG.fillna(0)
df2008_4_GANGDONG = df2008_4_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_4_GANGDONG)
#print('\n')

#3 - 강북구
df2008_4_GANGBUK = df2008_4[df2008_4['측정소명'] == '강북구']
df2008_4_GANGBUK = df2008_4_GANGBUK.groupby('날짜').mean()
df2008_4_GANGBUK['PM10'] = round(df2008_4_GANGBUK['PM10'], 2)
df2008_4_GANGBUK = df2008_4_GANGBUK.fillna(0)
df2008_4_GANGBUK = df2008_4_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_4_GANGBUK)
#print('\n')

#4 - 강서구
df2008_4_GANGSEO = df2008_4[df2008_4['측정소명'] == '강서구']
df2008_4_GANGSEO = df2008_4_GANGSEO.groupby('날짜').mean()
df2008_4_GANGSEO['PM10'] = round(df2008_4_GANGSEO['PM10'], 2)
df2008_4_GANGSEO = df2008_4_GANGSEO.fillna(0)
df2008_4_GANGSEO = df2008_4_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_4_GANGSEO)
#print('\n')

#5 - 관악구
df2008_4_GWANAK = df2008_4[df2008_4['측정소명'] == '관악구']
df2008_4_GWANAK = df2008_4_GWANAK.groupby('날짜').mean()
df2008_4_GWANAK['PM10'] = round(df2008_4_GWANAK['PM10'], 2)
df2008_4_GWANAK = df2008_4_GWANAK.fillna(0)
df2008_4_GWANAK = df2008_4_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_4_GWANAK)
#print('\n')

#6 - 광진구
df2008_4_GWANGJIN = df2008_4[df2008_4['측정소명'] == '광진구']
df2008_4_GWANGJIN = df2008_4_GWANGJIN.groupby('날짜').mean()
df2008_4_GWANGJIN['PM10'] = round(df2008_4_GWANGJIN['PM10'], 2)
df2008_4_GWANGJIN = df2008_4_GWANGJIN.fillna(0)
df2008_4_GWANGJIN = df2008_4_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_4_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_4_GURO = df2008_4[df2008_4['측정소명'] == '구로구']
df2008_4_GURO = df2008_4_GURO.groupby('날짜').mean()
df2008_4_GURO['PM10'] = round(df2008_4_GURO['PM10'], 2)
df2008_4_GURO = df2008_4_GURO.fillna(0)
df2008_4_GURO = df2008_4_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_4_GURO)
#print('\n')

#8 - 금천구
df2008_4_GEUMCHEON = df2008_4[df2008_4['측정소명'] == '금천구']
df2008_4_GEUMCHEON = df2008_4_GEUMCHEON.groupby('날짜').mean()
df2008_4_GEUMCHEON['PM10'] = round(df2008_4_GEUMCHEON['PM10'], 2)
df2008_4_GEUMCHEON = df2008_4_GEUMCHEON.fillna(0)
df2008_4_GEUMCHEON = df2008_4_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_4_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_4_NOWON = df2008_4[df2008_4['측정소명'] == '노원구']
df2008_4_NOWON = df2008_4_NOWON.groupby('날짜').mean()
df2008_4_NOWON['PM10'] = round(df2008_4_NOWON['PM10'], 2)
df2008_4_NOWON = df2008_4_NOWON.fillna(0)
df2008_4_NOWON = df2008_4_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_4_NOWON)
#print('\n')

#10 - 도봉구
df2008_4_DOBONG = df2008_4[df2008_4['측정소명'] == '도봉구']
df2008_4_DOBONG = df2008_4_DOBONG.groupby('날짜').mean()
df2008_4_DOBONG['PM10'] = round(df2008_4_DOBONG['PM10'], 2)
df2008_4_DOBONG = df2008_4_DOBONG.fillna(0)
df2008_4_DOBONG = df2008_4_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_4_DOBONG)
#print('\n')

#11 - 동대문구
df2008_4_DONGDAEMUN = df2008_4[df2008_4['측정소명'] == '동대문구']
df2008_4_DONGDAEMUN = df2008_4_DONGDAEMUN.groupby('날짜').mean()
df2008_4_DONGDAEMUN['PM10'] = round(df2008_4_DONGDAEMUN['PM10'], 2)
df2008_4_DONGDAEMUN = df2008_4_DONGDAEMUN.fillna(0)
df2008_4_DONGDAEMUN = df2008_4_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_4_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_4_DONGJAK = df2008_4[df2008_4['측정소명'] == '동작구']
df2008_4_DONGJAK = df2008_4_DONGJAK.groupby('날짜').mean()
df2008_4_DONGJAK['PM10'] = round(df2008_4_DONGJAK['PM10'], 2)
df2008_4_DONGJAK = df2008_4_DONGJAK.fillna(0)
df2008_4_DONGJAK = df2008_4_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_4_DONGJAK)
#print('\n')

#13 - 마포구
df2008_4_MAPO = df2008_4[df2008_4['측정소명'] == '마포구']
df2008_4_MAPO = df2008_4_MAPO.groupby('날짜').mean()
df2008_4_MAPO['PM10'] = round(df2008_4_MAPO['PM10'], 2)
df2008_4_MAPO = df2008_4_MAPO.fillna(0)
df2008_4_MAPO = df2008_4_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_4_MAPO)
#print('\n')

#14 - 서대문구
df2008_4_SEODAEMUN = df2008_4[df2008_4['측정소명'] == '서대문구']
df2008_4_SEODAEMUN = df2008_4_SEODAEMUN.groupby('날짜').mean()
df2008_4_SEODAEMUN['PM10'] = round(df2008_4_SEODAEMUN['PM10'], 2)
df2008_4_SEODAEMUN = df2008_4_SEODAEMUN.fillna(0)
df2008_4_SEODAEMUN = df2008_4_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_4_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_4_SEOCHO = df2008_4[df2008_4['측정소명'] == '서초구']
df2008_4_SEOCHO = df2008_4_SEOCHO.groupby('날짜').mean()
df2008_4_SEOCHO['PM10'] = round(df2008_4_SEOCHO['PM10'], 2)
df2008_4_SEOCHO = df2008_4_SEOCHO.fillna(0)
df2008_4_SEOCHO = df2008_4_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_4_SEOCHO)
#print('\n')

#16 - 성동구
df2008_4_SEONGDONG = df2008_4[df2008_4['측정소명'] == '성동구']
df2008_4_SEONGDONG = df2008_4_SEONGDONG.groupby('날짜').mean()
df2008_4_SEONGDONG['PM10'] = round(df2008_4_SEONGDONG['PM10'], 2)
df2008_4_SEONGDONG = df2008_4_SEONGDONG.fillna(0)
df2008_4_SEONGDONG = df2008_4_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_4_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_4_SEONGBUK = df2008_4[df2008_4['측정소명'] == '성북구']
df2008_4_SEONGBUK = df2008_4_SEONGBUK.groupby('날짜').mean()
df2008_4_SEONGBUK['PM10'] = round(df2008_4_SEONGBUK['PM10'], 2)
df2008_4_SEONGBUK = df2008_4_SEONGBUK.fillna(0)
df2008_4_SEONGBUK = df2008_4_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_4_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_4_SONGPA = df2008_4[df2008_4['측정소명'] == '송파구']
df2008_4_SONGPA = df2008_4_SONGPA.groupby('날짜').mean()
df2008_4_SONGPA['PM10'] = round(df2008_4_SONGPA['PM10'], 2)
df2008_4_SONGPA = df2008_4_SONGPA.fillna(0)
df2008_4_SONGPA = df2008_4_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_4_SONGPA)
#print('\n')

#19 - 양천구
df2008_4_YANGCHEON = df2008_4[df2008_4['측정소명'] == '양천구']
df2008_4_YANGCHEON = df2008_4_YANGCHEON.groupby('날짜').mean()
df2008_4_YANGCHEON['PM10'] = round(df2008_4_YANGCHEON['PM10'], 2)
df2008_4_YANGCHEON = df2008_4_YANGCHEON.fillna(0)
df2008_4_YANGCHEON = df2008_4_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_4_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_4_YEONGDEUNGPO = df2008_4[df2008_4['측정소명'] == '영등포구']
df2008_4_YEONGDEUNGPO = df2008_4_YEONGDEUNGPO.groupby('날짜').mean()
df2008_4_YEONGDEUNGPO['PM10'] = round(df2008_4_YEONGDEUNGPO['PM10'], 2)
df2008_4_YEONGDEUNGPO = df2008_4_YEONGDEUNGPO.fillna(0)
df2008_4_YEONGDEUNGPO = df2008_4_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_4_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_4_YONGSAN = df2008_4[df2008_4['측정소명'] == '용산구']
df2008_4_YONGSAN = df2008_4_YONGSAN.groupby('날짜').mean()
df2008_4_YONGSAN['PM10'] = round(df2008_4_YONGSAN['PM10'], 2)
df2008_4_YONGSAN = df2008_4_YONGSAN.fillna(0)
df2008_4_YONGSAN = df2008_4_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_4_YONGSAN)
#print('\n')

#22 - 은평구
df2008_4_EUNPYEONG = df2008_4[df2008_4['측정소명'] == '은평구']
df2008_4_EUNPYEONG = df2008_4_EUNPYEONG.groupby('날짜').mean()
df2008_4_EUNPYEONG['PM10'] = round(df2008_4_EUNPYEONG['PM10'], 2)
df2008_4_EUNPYEONG = df2008_4_EUNPYEONG.fillna(0)
df2008_4_EUNPYEONG = df2008_4_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_4_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_4_JONGNO = df2008_4[df2008_4['측정소명'] == '종로구']
df2008_4_JONGNO = df2008_4_JONGNO.groupby('날짜').mean()
df2008_4_JONGNO['PM10'] = round(df2008_4_JONGNO['PM10'], 2)
df2008_4_JONGNO = df2008_4_JONGNO.fillna(0)
df2008_4_JONGNO = df2008_4_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_4_JONGNO)
#print('\n')

#24 - 중구
df2008_4_JUNG = df2008_4[df2008_4['측정소명'] == '중구']
df2008_4_JUNG = df2008_4_JUNG.groupby('날짜').mean()
df2008_4_JUNG['PM10'] = round(df2008_4_JUNG['PM10'], 2)
df2008_4_JUNG = df2008_4_JUNG.fillna(0)
df2008_4_JUNG = df2008_4_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_4_JUNG)
#print('\n')

#25 - 중랑구
df2008_4_JUNGNANG = df2008_4[df2008_4['측정소명'] == '중랑구']
df2008_4_JUNGNANG = df2008_4_JUNGNANG.groupby('날짜').mean()
df2008_4_JUNGNANG['PM10'] = round(df2008_4_JUNGNANG['PM10'], 2)
df2008_4_JUNGNANG = df2008_4_JUNGNANG.fillna(0)
df2008_4_JUNGNANG = df2008_4_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_4_JUNGNANG)

#======================
my2008_4 = pd.concat([df2008_4_GANGNAM, df2008_4_GANGDONG, df2008_4_GANGBUK, df2008_4_GANGSEO,
                      df2008_4_GWANAK, df2008_4_GWANGJIN, df2008_4_GURO, df2008_4_GEUMCHEON,
                      df2008_4_NOWON, df2008_4_DOBONG, df2008_4_DONGDAEMUN, df2008_4_DONGJAK,
                      df2008_4_MAPO, df2008_4_SEODAEMUN, df2008_4_SEOCHO, df2008_4_SEONGDONG,
                      df2008_4_SEONGBUK, df2008_4_SONGPA, df2008_4_YANGCHEON, df2008_4_YEONGDEUNGPO,
                      df2008_4_YONGSAN, df2008_4_EUNPYEONG, df2008_4_JONGNO, df2008_4_JUNG,
                      df2008_4_JUNGNANG], axis = 1)
#2008년 5월

#1 - 강남구
df2008_5_GANGNAM = df2008_5[df2008_5['측정소명'] == '강남구']
df2008_5_GANGNAM = df2008_5_GANGNAM.groupby('날짜').mean()
df2008_5_GANGNAM['PM10'] = round(df2008_5_GANGNAM['PM10'], 2)
df2008_5_GANGNAM = df2008_5_GANGNAM.fillna(0)
df2008_5_GANGNAM = df2008_5_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_5_GANGNAM)
#print('\n')

#2 - 강동구
df2008_5_GANGDONG = df2008_5[df2008_5['측정소명'] == '강동구']
df2008_5_GANGDONG = df2008_5_GANGDONG.groupby('날짜').mean()
df2008_5_GANGDONG['PM10'] = round(df2008_5_GANGDONG['PM10'], 2)
df2008_5_GANGDONG = df2008_5_GANGDONG.fillna(0)
df2008_5_GANGDONG = df2008_5_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_5_GANGDONG)
#print('\n')

#3 - 강북구
df2008_5_GANGBUK = df2008_5[df2008_5['측정소명'] == '강북구']
df2008_5_GANGBUK = df2008_5_GANGBUK.groupby('날짜').mean()
df2008_5_GANGBUK['PM10'] = round(df2008_5_GANGBUK['PM10'], 2)
df2008_5_GANGBUK = df2008_5_GANGBUK.fillna(0)
df2008_5_GANGBUK = df2008_5_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_5_GANGBUK)
#print('\n')

#4 - 강서구
df2008_5_GANGSEO = df2008_5[df2008_5['측정소명'] == '강서구']
df2008_5_GANGSEO = df2008_5_GANGSEO.groupby('날짜').mean()
df2008_5_GANGSEO['PM10'] = round(df2008_5_GANGSEO['PM10'], 2)
df2008_5_GANGSEO = df2008_5_GANGSEO.fillna(0)
df2008_5_GANGSEO = df2008_5_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_5_GANGSEO)
#print('\n')

#5 - 관악구
df2008_5_GWANAK = df2008_5[df2008_5['측정소명'] == '관악구']
df2008_5_GWANAK = df2008_5_GWANAK.groupby('날짜').mean()
df2008_5_GWANAK['PM10'] = round(df2008_5_GWANAK['PM10'], 2)
df2008_5_GWANAK = df2008_5_GWANAK.fillna(0)
df2008_5_GWANAK = df2008_5_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_5_GWANAK)
#print('\n')

#6 - 광진구
df2008_5_GWANGJIN = df2008_5[df2008_5['측정소명'] == '광진구']
df2008_5_GWANGJIN = df2008_5_GWANGJIN.groupby('날짜').mean()
df2008_5_GWANGJIN['PM10'] = round(df2008_5_GWANGJIN['PM10'], 2)
df2008_5_GWANGJIN = df2008_5_GWANGJIN.fillna(0)
df2008_5_GWANGJIN = df2008_5_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_5_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_5_GURO = df2008_5[df2008_5['측정소명'] == '구로구']
df2008_5_GURO = df2008_5_GURO.groupby('날짜').mean()
df2008_5_GURO['PM10'] = round(df2008_5_GURO['PM10'], 2)
df2008_5_GURO = df2008_5_GURO.fillna(0)
df2008_5_GURO = df2008_5_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_5_GURO)
#print('\n')

#8 - 금천구
df2008_5_GEUMCHEON = df2008_5[df2008_5['측정소명'] == '금천구']
df2008_5_GEUMCHEON = df2008_5_GEUMCHEON.groupby('날짜').mean()
df2008_5_GEUMCHEON['PM10'] = round(df2008_5_GEUMCHEON['PM10'], 2)
df2008_5_GEUMCHEON = df2008_5_GEUMCHEON.fillna(0)
df2008_5_GEUMCHEON = df2008_5_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_5_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_5_NOWON = df2008_5[df2008_5['측정소명'] == '노원구']
df2008_5_NOWON = df2008_5_NOWON.groupby('날짜').mean()
df2008_5_NOWON['PM10'] = round(df2008_5_NOWON['PM10'], 2)
df2008_5_NOWON = df2008_5_NOWON.fillna(0)
df2008_5_NOWON = df2008_5_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_5_NOWON)
#print('\n')

#10 - 도봉구
df2008_5_DOBONG = df2008_5[df2008_5['측정소명'] == '도봉구']
df2008_5_DOBONG = df2008_5_DOBONG.groupby('날짜').mean()
df2008_5_DOBONG['PM10'] = round(df2008_5_DOBONG['PM10'], 2)
df2008_5_DOBONG = df2008_5_DOBONG.fillna(0)
df2008_5_DOBONG = df2008_5_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_5_DOBONG)
#print('\n')

#11 - 동대문구
df2008_5_DONGDAEMUN = df2008_5[df2008_5['측정소명'] == '동대문구']
df2008_5_DONGDAEMUN = df2008_5_DONGDAEMUN.groupby('날짜').mean()
df2008_5_DONGDAEMUN['PM10'] = round(df2008_5_DONGDAEMUN['PM10'], 2)
df2008_5_DONGDAEMUN = df2008_5_DONGDAEMUN.fillna(0)
df2008_5_DONGDAEMUN = df2008_5_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_5_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_5_DONGJAK = df2008_5[df2008_5['측정소명'] == '동작구']
df2008_5_DONGJAK = df2008_5_DONGJAK.groupby('날짜').mean()
df2008_5_DONGJAK['PM10'] = round(df2008_5_DONGJAK['PM10'], 2)
df2008_5_DONGJAK = df2008_5_DONGJAK.fillna(0)
df2008_5_DONGJAK = df2008_5_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_5_DONGJAK)
#print('\n')

#13 - 마포구
df2008_5_MAPO = df2008_5[df2008_5['측정소명'] == '마포구']
df2008_5_MAPO = df2008_5_MAPO.groupby('날짜').mean()
df2008_5_MAPO['PM10'] = round(df2008_5_MAPO['PM10'], 2)
df2008_5_MAPO = df2008_5_MAPO.fillna(0)
df2008_5_MAPO = df2008_5_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_5_MAPO)
#print('\n')

#14 - 서대문구
df2008_5_SEODAEMUN = df2008_5[df2008_5['측정소명'] == '서대문구']
df2008_5_SEODAEMUN = df2008_5_SEODAEMUN.groupby('날짜').mean()
df2008_5_SEODAEMUN['PM10'] = round(df2008_5_SEODAEMUN['PM10'], 2)
df2008_5_SEODAEMUN = df2008_5_SEODAEMUN.fillna(0)
df2008_5_SEODAEMUN = df2008_5_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_5_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_5_SEOCHO = df2008_5[df2008_5['측정소명'] == '서초구']
df2008_5_SEOCHO = df2008_5_SEOCHO.groupby('날짜').mean()
df2008_5_SEOCHO['PM10'] = round(df2008_5_SEOCHO['PM10'], 2)
df2008_5_SEOCHO = df2008_5_SEOCHO.fillna(0)
df2008_5_SEOCHO = df2008_5_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_5_SEOCHO)
#print('\n')

#16 - 성동구
df2008_5_SEONGDONG = df2008_5[df2008_5['측정소명'] == '성동구']
df2008_5_SEONGDONG = df2008_5_SEONGDONG.groupby('날짜').mean()
df2008_5_SEONGDONG['PM10'] = round(df2008_5_SEONGDONG['PM10'], 2)
df2008_5_SEONGDONG = df2008_5_SEONGDONG.fillna(0)
df2008_5_SEONGDONG = df2008_5_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_5_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_5_SEONGBUK = df2008_5[df2008_5['측정소명'] == '성북구']
df2008_5_SEONGBUK = df2008_5_SEONGBUK.groupby('날짜').mean()
df2008_5_SEONGBUK['PM10'] = round(df2008_5_SEONGBUK['PM10'], 2)
df2008_5_SEONGBUK = df2008_5_SEONGBUK.fillna(0)
df2008_5_SEONGBUK = df2008_5_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_5_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_5_SONGPA = df2008_5[df2008_5['측정소명'] == '송파구']
df2008_5_SONGPA = df2008_5_SONGPA.groupby('날짜').mean()
df2008_5_SONGPA['PM10'] = round(df2008_5_SONGPA['PM10'], 2)
df2008_5_SONGPA = df2008_5_SONGPA.fillna(0)
df2008_5_SONGPA = df2008_5_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_5_SONGPA)
#print('\n')

#19 - 양천구
df2008_5_YANGCHEON = df2008_5[df2008_5['측정소명'] == '양천구']
df2008_5_YANGCHEON = df2008_5_YANGCHEON.groupby('날짜').mean()
df2008_5_YANGCHEON['PM10'] = round(df2008_5_YANGCHEON['PM10'], 2)
df2008_5_YANGCHEON = df2008_5_YANGCHEON.fillna(0)
df2008_5_YANGCHEON = df2008_5_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_5_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_5_YEONGDEUNGPO = df2008_5[df2008_5['측정소명'] == '영등포구']
df2008_5_YEONGDEUNGPO = df2008_5_YEONGDEUNGPO.groupby('날짜').mean()
df2008_5_YEONGDEUNGPO['PM10'] = round(df2008_5_YEONGDEUNGPO['PM10'], 2)
df2008_5_YEONGDEUNGPO = df2008_5_YEONGDEUNGPO.fillna(0)
df2008_5_YEONGDEUNGPO = df2008_5_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_5_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_5_YONGSAN = df2008_5[df2008_5['측정소명'] == '용산구']
df2008_5_YONGSAN = df2008_5_YONGSAN.groupby('날짜').mean()
df2008_5_YONGSAN['PM10'] = round(df2008_5_YONGSAN['PM10'], 2)
df2008_5_YONGSAN = df2008_5_YONGSAN.fillna(0)
df2008_5_YONGSAN = df2008_5_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_5_YONGSAN)
#print('\n')

#22 - 은평구
df2008_5_EUNPYEONG = df2008_5[df2008_5['측정소명'] == '은평구']
df2008_5_EUNPYEONG = df2008_5_EUNPYEONG.groupby('날짜').mean()
df2008_5_EUNPYEONG['PM10'] = round(df2008_5_EUNPYEONG['PM10'], 2)
df2008_5_EUNPYEONG = df2008_5_EUNPYEONG.fillna(0)
df2008_5_EUNPYEONG = df2008_5_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_5_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_5_JONGNO = df2008_5[df2008_5['측정소명'] == '종로구']
df2008_5_JONGNO = df2008_5_JONGNO.groupby('날짜').mean()
df2008_5_JONGNO['PM10'] = round(df2008_5_JONGNO['PM10'], 2)
df2008_5_JONGNO = df2008_5_JONGNO.fillna(0)
df2008_5_JONGNO = df2008_5_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_5_JONGNO)
#print('\n')

#24 - 중구
df2008_5_JUNG = df2008_5[df2008_5['측정소명'] == '중구']
df2008_5_JUNG = df2008_5_JUNG.groupby('날짜').mean()
df2008_5_JUNG['PM10'] = round(df2008_5_JUNG['PM10'], 2)
df2008_5_JUNG = df2008_5_JUNG.fillna(0)
df2008_5_JUNG = df2008_5_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_5_JUNG)
#print('\n')

#25 - 중랑구
df2008_5_JUNGNANG = df2008_5[df2008_5['측정소명'] == '중랑구']
df2008_5_JUNGNANG = df2008_5_JUNGNANG.groupby('날짜').mean()
df2008_5_JUNGNANG['PM10'] = round(df2008_5_JUNGNANG['PM10'], 2)
df2008_5_JUNGNANG = df2008_5_JUNGNANG.fillna(0)
df2008_5_JUNGNANG = df2008_5_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_5_JUNGNANG)

#======================
my2008_5 = pd.concat([df2008_5_GANGNAM, df2008_5_GANGDONG, df2008_5_GANGBUK, df2008_5_GANGSEO,
                      df2008_5_GWANAK, df2008_5_GWANGJIN, df2008_5_GURO, df2008_5_GEUMCHEON,
                      df2008_5_NOWON, df2008_5_DOBONG, df2008_5_DONGDAEMUN, df2008_5_DONGJAK,
                      df2008_5_MAPO, df2008_5_SEODAEMUN, df2008_5_SEOCHO, df2008_5_SEONGDONG,
                      df2008_5_SEONGBUK, df2008_5_SONGPA, df2008_5_YANGCHEON, df2008_5_YEONGDEUNGPO,
                      df2008_5_YONGSAN, df2008_5_EUNPYEONG, df2008_5_JONGNO, df2008_5_JUNG,
                      df2008_5_JUNGNANG], axis = 1)

#2008년 6월

#1 - 강남구
df2008_6_GANGNAM = df2008_6[df2008_6['측정소명'] == '강남구']
df2008_6_GANGNAM = df2008_6_GANGNAM.groupby('날짜').mean()
df2008_6_GANGNAM['PM10'] = round(df2008_6_GANGNAM['PM10'], 2)
df2008_6_GANGNAM = df2008_6_GANGNAM.fillna(0)
df2008_6_GANGNAM = df2008_6_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_6_GANGNAM)
#print('\n')

#2 - 강동구
df2008_6_GANGDONG = df2008_6[df2008_6['측정소명'] == '강동구']
df2008_6_GANGDONG = df2008_6_GANGDONG.groupby('날짜').mean()
df2008_6_GANGDONG['PM10'] = round(df2008_6_GANGDONG['PM10'], 2)
df2008_6_GANGDONG = df2008_6_GANGDONG.fillna(0)
df2008_6_GANGDONG = df2008_6_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_6_GANGDONG)
#print('\n')

#3 - 강북구
df2008_6_GANGBUK = df2008_6[df2008_6['측정소명'] == '강북구']
df2008_6_GANGBUK = df2008_6_GANGBUK.groupby('날짜').mean()
df2008_6_GANGBUK['PM10'] = round(df2008_6_GANGBUK['PM10'], 2)
df2008_6_GANGBUK = df2008_6_GANGBUK.fillna(0)
df2008_6_GANGBUK = df2008_6_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_6_GANGBUK)
#print('\n')

#4 - 강서구
df2008_6_GANGSEO = df2008_6[df2008_6['측정소명'] == '강서구']
df2008_6_GANGSEO = df2008_6_GANGSEO.groupby('날짜').mean()
df2008_6_GANGSEO['PM10'] = round(df2008_6_GANGSEO['PM10'], 2)
df2008_6_GANGSEO = df2008_6_GANGSEO.fillna(0)
df2008_6_GANGSEO = df2008_6_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_6_GANGSEO)
#print('\n')

#5 - 관악구
df2008_6_GWANAK = df2008_6[df2008_6['측정소명'] == '관악구']
df2008_6_GWANAK = df2008_6_GWANAK.groupby('날짜').mean()
df2008_6_GWANAK['PM10'] = round(df2008_6_GWANAK['PM10'], 2)
df2008_6_GWANAK = df2008_6_GWANAK.fillna(0)
df2008_6_GWANAK = df2008_6_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_6_GWANAK)
#print('\n')

#6 - 광진구
df2008_6_GWANGJIN = df2008_6[df2008_6['측정소명'] == '광진구']
df2008_6_GWANGJIN = df2008_6_GWANGJIN.groupby('날짜').mean()
df2008_6_GWANGJIN['PM10'] = round(df2008_6_GWANGJIN['PM10'], 2)
df2008_6_GWANGJIN = df2008_6_GWANGJIN.fillna(0)
df2008_6_GWANGJIN = df2008_6_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_6_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_6_GURO = df2008_6[df2008_6['측정소명'] == '구로구']
df2008_6_GURO = df2008_6_GURO.groupby('날짜').mean()
df2008_6_GURO['PM10'] = round(df2008_6_GURO['PM10'], 2)
df2008_6_GURO = df2008_6_GURO.fillna(0)
df2008_6_GURO = df2008_6_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_6_GURO)
#print('\n')

#8 - 금천구
df2008_6_GEUMCHEON = df2008_6[df2008_6['측정소명'] == '금천구']
df2008_6_GEUMCHEON = df2008_6_GEUMCHEON.groupby('날짜').mean()
df2008_6_GEUMCHEON['PM10'] = round(df2008_6_GEUMCHEON['PM10'], 2)
df2008_6_GEUMCHEON = df2008_6_GEUMCHEON.fillna(0)
df2008_6_GEUMCHEON = df2008_6_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_6_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_6_NOWON = df2008_6[df2008_6['측정소명'] == '노원구']
df2008_6_NOWON = df2008_6_NOWON.groupby('날짜').mean()
df2008_6_NOWON['PM10'] = round(df2008_6_NOWON['PM10'], 2)
df2008_6_NOWON = df2008_6_NOWON.fillna(0)
df2008_6_NOWON = df2008_6_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_6_NOWON)
#print('\n')

#10 - 도봉구
df2008_6_DOBONG = df2008_6[df2008_6['측정소명'] == '도봉구']
df2008_6_DOBONG = df2008_6_DOBONG.groupby('날짜').mean()
df2008_6_DOBONG['PM10'] = round(df2008_6_DOBONG['PM10'], 2)
df2008_6_DOBONG = df2008_6_DOBONG.fillna(0)
df2008_6_DOBONG = df2008_6_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_6_DOBONG)
#print('\n')

#11 - 동대문구
df2008_6_DONGDAEMUN = df2008_6[df2008_6['측정소명'] == '동대문구']
df2008_6_DONGDAEMUN = df2008_6_DONGDAEMUN.groupby('날짜').mean()
df2008_6_DONGDAEMUN['PM10'] = round(df2008_6_DONGDAEMUN['PM10'], 2)
df2008_6_DONGDAEMUN = df2008_6_DONGDAEMUN.fillna(0)
df2008_6_DONGDAEMUN = df2008_6_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_6_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_6_DONGJAK = df2008_6[df2008_6['측정소명'] == '동작구']
df2008_6_DONGJAK = df2008_6_DONGJAK.groupby('날짜').mean()
df2008_6_DONGJAK['PM10'] = round(df2008_6_DONGJAK['PM10'], 2)
df2008_6_DONGJAK = df2008_6_DONGJAK.fillna(0)
df2008_6_DONGJAK = df2008_6_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_6_DONGJAK)
#print('\n')

#13 - 마포구
df2008_6_MAPO = df2008_6[df2008_6['측정소명'] == '마포구']
df2008_6_MAPO = df2008_6_MAPO.groupby('날짜').mean()
df2008_6_MAPO['PM10'] = round(df2008_6_MAPO['PM10'], 2)
df2008_6_MAPO = df2008_6_MAPO.fillna(0)
df2008_6_MAPO = df2008_6_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_6_MAPO)
#print('\n')

#14 - 서대문구
df2008_6_SEODAEMUN = df2008_6[df2008_6['측정소명'] == '서대문구']
df2008_6_SEODAEMUN = df2008_6_SEODAEMUN.groupby('날짜').mean()
df2008_6_SEODAEMUN['PM10'] = round(df2008_6_SEODAEMUN['PM10'], 2)
df2008_6_SEODAEMUN = df2008_6_SEODAEMUN.fillna(0)
df2008_6_SEODAEMUN = df2008_6_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_6_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_6_SEOCHO = df2008_6[df2008_6['측정소명'] == '서초구']
df2008_6_SEOCHO = df2008_6_SEOCHO.groupby('날짜').mean()
df2008_6_SEOCHO['PM10'] = round(df2008_6_SEOCHO['PM10'], 2)
df2008_6_SEOCHO = df2008_6_SEOCHO.fillna(0)
df2008_6_SEOCHO = df2008_6_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_6_SEOCHO)
#print('\n')

#16 - 성동구
df2008_6_SEONGDONG = df2008_6[df2008_6['측정소명'] == '성동구']
df2008_6_SEONGDONG = df2008_6_SEONGDONG.groupby('날짜').mean()
df2008_6_SEONGDONG['PM10'] = round(df2008_6_SEONGDONG['PM10'], 2)
df2008_6_SEONGDONG = df2008_6_SEONGDONG.fillna(0)
df2008_6_SEONGDONG = df2008_6_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_6_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_6_SEONGBUK = df2008_6[df2008_6['측정소명'] == '성북구']
df2008_6_SEONGBUK = df2008_6_SEONGBUK.groupby('날짜').mean()
df2008_6_SEONGBUK['PM10'] = round(df2008_6_SEONGBUK['PM10'], 2)
df2008_6_SEONGBUK = df2008_6_SEONGBUK.fillna(0)
df2008_6_SEONGBUK = df2008_6_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_6_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_6_SONGPA = df2008_6[df2008_6['측정소명'] == '송파구']
df2008_6_SONGPA = df2008_6_SONGPA.groupby('날짜').mean()
df2008_6_SONGPA['PM10'] = round(df2008_6_SONGPA['PM10'], 2)
df2008_6_SONGPA = df2008_6_SONGPA.fillna(0)
df2008_6_SONGPA = df2008_6_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_6_SONGPA)
#print('\n')

#19 - 양천구
df2008_6_YANGCHEON = df2008_6[df2008_6['측정소명'] == '양천구']
df2008_6_YANGCHEON = df2008_6_YANGCHEON.groupby('날짜').mean()
df2008_6_YANGCHEON['PM10'] = round(df2008_6_YANGCHEON['PM10'], 2)
df2008_6_YANGCHEON = df2008_6_YANGCHEON.fillna(0)
df2008_6_YANGCHEON = df2008_6_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_6_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_6_YEONGDEUNGPO = df2008_6[df2008_6['측정소명'] == '영등포구']
df2008_6_YEONGDEUNGPO = df2008_6_YEONGDEUNGPO.groupby('날짜').mean()
df2008_6_YEONGDEUNGPO['PM10'] = round(df2008_6_YEONGDEUNGPO['PM10'], 2)
df2008_6_YEONGDEUNGPO = df2008_6_YEONGDEUNGPO.fillna(0)
df2008_6_YEONGDEUNGPO = df2008_6_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_6_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_6_YONGSAN = df2008_6[df2008_6['측정소명'] == '용산구']
df2008_6_YONGSAN = df2008_6_YONGSAN.groupby('날짜').mean()
df2008_6_YONGSAN['PM10'] = round(df2008_6_YONGSAN['PM10'], 2)
df2008_6_YONGSAN = df2008_6_YONGSAN.fillna(0)
df2008_6_YONGSAN = df2008_6_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_6_YONGSAN)
#print('\n')

#22 - 은평구
df2008_6_EUNPYEONG = df2008_6[df2008_6['측정소명'] == '은평구']
df2008_6_EUNPYEONG = df2008_6_EUNPYEONG.groupby('날짜').mean()
df2008_6_EUNPYEONG['PM10'] = round(df2008_6_EUNPYEONG['PM10'], 2)
df2008_6_EUNPYEONG = df2008_6_EUNPYEONG.fillna(0)
df2008_6_EUNPYEONG = df2008_6_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_6_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_6_JONGNO = df2008_6[df2008_6['측정소명'] == '종로구']
df2008_6_JONGNO = df2008_6_JONGNO.groupby('날짜').mean()
df2008_6_JONGNO['PM10'] = round(df2008_6_JONGNO['PM10'], 2)
df2008_6_JONGNO = df2008_6_JONGNO.fillna(0)
df2008_6_JONGNO = df2008_6_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_6_JONGNO)
#print('\n')

#24 - 중구
df2008_6_JUNG = df2008_6[df2008_6['측정소명'] == '중구']
df2008_6_JUNG = df2008_6_JUNG.groupby('날짜').mean()
df2008_6_JUNG['PM10'] = round(df2008_6_JUNG['PM10'], 2)
df2008_6_JUNG = df2008_6_JUNG.fillna(0)
df2008_6_JUNG = df2008_6_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_6_JUNG)
#print('\n')

#25 - 중랑구
df2008_6_JUNGNANG = df2008_6[df2008_6['측정소명'] == '중랑구']
df2008_6_JUNGNANG = df2008_6_JUNGNANG.groupby('날짜').mean()
df2008_6_JUNGNANG['PM10'] = round(df2008_6_JUNGNANG['PM10'], 2)
df2008_6_JUNGNANG = df2008_6_JUNGNANG.fillna(0)
df2008_6_JUNGNANG = df2008_6_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_6_JUNGNANG)

#======================
my2008_6 = pd.concat([df2008_6_GANGNAM, df2008_6_GANGDONG, df2008_6_GANGBUK, df2008_6_GANGSEO,
                      df2008_6_GWANAK, df2008_6_GWANGJIN, df2008_6_GURO, df2008_6_GEUMCHEON,
                      df2008_6_NOWON, df2008_6_DOBONG, df2008_6_DONGDAEMUN, df2008_6_DONGJAK,
                      df2008_6_MAPO, df2008_6_SEODAEMUN, df2008_6_SEOCHO, df2008_6_SEONGDONG,
                      df2008_6_SEONGBUK, df2008_6_SONGPA, df2008_6_YANGCHEON, df2008_6_YEONGDEUNGPO,
                      df2008_6_YONGSAN, df2008_6_EUNPYEONG, df2008_6_JONGNO, df2008_6_JUNG,
                      df2008_6_JUNGNANG], axis = 1)

#2008년 7월

#1 - 강남구
df2008_7_GANGNAM = df2008_7[df2008_7['측정소명'] == '강남구']
df2008_7_GANGNAM = df2008_7_GANGNAM.groupby('날짜').mean()
df2008_7_GANGNAM['PM10'] = round(df2008_7_GANGNAM['PM10'], 2)
df2008_7_GANGNAM = df2008_7_GANGNAM.fillna(0)
df2008_7_GANGNAM = df2008_7_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_7_GANGNAM)
#print('\n')

#2 - 강동구
df2008_7_GANGDONG = df2008_7[df2008_7['측정소명'] == '강동구']
df2008_7_GANGDONG = df2008_7_GANGDONG.groupby('날짜').mean()
df2008_7_GANGDONG['PM10'] = round(df2008_7_GANGDONG['PM10'], 2)
df2008_7_GANGDONG = df2008_7_GANGDONG.fillna(0)
df2008_7_GANGDONG = df2008_7_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_7_GANGDONG)
#print('\n')

#3 - 강북구
df2008_7_GANGBUK = df2008_7[df2008_7['측정소명'] == '강북구']
df2008_7_GANGBUK = df2008_7_GANGBUK.groupby('날짜').mean()
df2008_7_GANGBUK['PM10'] = round(df2008_7_GANGBUK['PM10'], 2)
df2008_7_GANGBUK = df2008_7_GANGBUK.fillna(0)
df2008_7_GANGBUK = df2008_7_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_7_GANGBUK)
#print('\n')

#4 - 강서구
df2008_7_GANGSEO = df2008_7[df2008_7['측정소명'] == '강서구']
df2008_7_GANGSEO = df2008_7_GANGSEO.groupby('날짜').mean()
df2008_7_GANGSEO['PM10'] = round(df2008_7_GANGSEO['PM10'], 2)
df2008_7_GANGSEO = df2008_7_GANGSEO.fillna(0)
df2008_7_GANGSEO = df2008_7_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_7_GANGSEO)
#print('\n')

#5 - 관악구
df2008_7_GWANAK = df2008_7[df2008_7['측정소명'] == '관악구']
df2008_7_GWANAK = df2008_7_GWANAK.groupby('날짜').mean()
df2008_7_GWANAK['PM10'] = round(df2008_7_GWANAK['PM10'], 2)
df2008_7_GWANAK = df2008_7_GWANAK.fillna(0)
df2008_7_GWANAK = df2008_7_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_7_GWANAK)
#print('\n')

#6 - 광진구
df2008_7_GWANGJIN = df2008_7[df2008_7['측정소명'] == '광진구']
df2008_7_GWANGJIN = df2008_7_GWANGJIN.groupby('날짜').mean()
df2008_7_GWANGJIN['PM10'] = round(df2008_7_GWANGJIN['PM10'], 2)
df2008_7_GWANGJIN = df2008_7_GWANGJIN.fillna(0)
df2008_7_GWANGJIN = df2008_7_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_7_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_7_GURO = df2008_7[df2008_7['측정소명'] == '구로구']
df2008_7_GURO = df2008_7_GURO.groupby('날짜').mean()
df2008_7_GURO['PM10'] = round(df2008_7_GURO['PM10'], 2)
df2008_7_GURO = df2008_7_GURO.fillna(0)
df2008_7_GURO = df2008_7_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_7_GURO)
#print('\n')

#8 - 금천구
df2008_7_GEUMCHEON = df2008_7[df2008_7['측정소명'] == '금천구']
df2008_7_GEUMCHEON = df2008_7_GEUMCHEON.groupby('날짜').mean()
df2008_7_GEUMCHEON['PM10'] = round(df2008_7_GEUMCHEON['PM10'], 2)
df2008_7_GEUMCHEON = df2008_7_GEUMCHEON.fillna(0)
df2008_7_GEUMCHEON = df2008_7_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_7_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_7_NOWON = df2008_7[df2008_7['측정소명'] == '노원구']
df2008_7_NOWON = df2008_7_NOWON.groupby('날짜').mean()
df2008_7_NOWON['PM10'] = round(df2008_7_NOWON['PM10'], 2)
df2008_7_NOWON = df2008_7_NOWON.fillna(0)
df2008_7_NOWON = df2008_7_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_7_NOWON)
#print('\n')

#10 - 도봉구
df2008_7_DOBONG = df2008_7[df2008_7['측정소명'] == '도봉구']
df2008_7_DOBONG = df2008_7_DOBONG.groupby('날짜').mean()
df2008_7_DOBONG['PM10'] = round(df2008_7_DOBONG['PM10'], 2)
df2008_7_DOBONG = df2008_7_DOBONG.fillna(0)
df2008_7_DOBONG = df2008_7_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_7_DOBONG)
#print('\n')

#11 - 동대문구
df2008_7_DONGDAEMUN = df2008_7[df2008_7['측정소명'] == '동대문구']
df2008_7_DONGDAEMUN = df2008_7_DONGDAEMUN.groupby('날짜').mean()
df2008_7_DONGDAEMUN['PM10'] = round(df2008_7_DONGDAEMUN['PM10'], 2)
df2008_7_DONGDAEMUN = df2008_7_DONGDAEMUN.fillna(0)
df2008_7_DONGDAEMUN = df2008_7_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_7_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_7_DONGJAK = df2008_7[df2008_7['측정소명'] == '동작구']
df2008_7_DONGJAK = df2008_7_DONGJAK.groupby('날짜').mean()
df2008_7_DONGJAK['PM10'] = round(df2008_7_DONGJAK['PM10'], 2)
df2008_7_DONGJAK = df2008_7_DONGJAK.fillna(0)
df2008_7_DONGJAK = df2008_7_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_7_DONGJAK)
#print('\n')

#13 - 마포구
df2008_7_MAPO = df2008_7[df2008_7['측정소명'] == '마포구']
df2008_7_MAPO = df2008_7_MAPO.groupby('날짜').mean()
df2008_7_MAPO['PM10'] = round(df2008_7_MAPO['PM10'], 2)
df2008_7_MAPO = df2008_7_MAPO.fillna(0)
df2008_7_MAPO = df2008_7_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_7_MAPO)
#print('\n')

#14 - 서대문구
df2008_7_SEODAEMUN = df2008_7[df2008_7['측정소명'] == '서대문구']
df2008_7_SEODAEMUN = df2008_7_SEODAEMUN.groupby('날짜').mean()
df2008_7_SEODAEMUN['PM10'] = round(df2008_7_SEODAEMUN['PM10'], 2)
df2008_7_SEODAEMUN = df2008_7_SEODAEMUN.fillna(0)
df2008_7_SEODAEMUN = df2008_7_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_7_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_7_SEOCHO = df2008_7[df2008_7['측정소명'] == '서초구']
df2008_7_SEOCHO = df2008_7_SEOCHO.groupby('날짜').mean()
df2008_7_SEOCHO['PM10'] = round(df2008_7_SEOCHO['PM10'], 2)
df2008_7_SEOCHO = df2008_7_SEOCHO.fillna(0)
df2008_7_SEOCHO = df2008_7_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_7_SEOCHO)
#print('\n')

#16 - 성동구
df2008_7_SEONGDONG = df2008_7[df2008_7['측정소명'] == '성동구']
df2008_7_SEONGDONG = df2008_7_SEONGDONG.groupby('날짜').mean()
df2008_7_SEONGDONG['PM10'] = round(df2008_7_SEONGDONG['PM10'], 2)
df2008_7_SEONGDONG = df2008_7_SEONGDONG.fillna(0)
df2008_7_SEONGDONG = df2008_7_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_7_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_7_SEONGBUK = df2008_7[df2008_7['측정소명'] == '성북구']
df2008_7_SEONGBUK = df2008_7_SEONGBUK.groupby('날짜').mean()
df2008_7_SEONGBUK['PM10'] = round(df2008_7_SEONGBUK['PM10'], 2)
df2008_7_SEONGBUK = df2008_7_SEONGBUK.fillna(0)
df2008_7_SEONGBUK = df2008_7_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_7_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_7_SONGPA = df2008_7[df2008_7['측정소명'] == '송파구']
df2008_7_SONGPA = df2008_7_SONGPA.groupby('날짜').mean()
df2008_7_SONGPA['PM10'] = round(df2008_7_SONGPA['PM10'], 2)
df2008_7_SONGPA = df2008_7_SONGPA.fillna(0)
df2008_7_SONGPA = df2008_7_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_7_SONGPA)
#print('\n')

#19 - 양천구
df2008_7_YANGCHEON = df2008_7[df2008_7['측정소명'] == '양천구']
df2008_7_YANGCHEON = df2008_7_YANGCHEON.groupby('날짜').mean()
df2008_7_YANGCHEON['PM10'] = round(df2008_7_YANGCHEON['PM10'], 2)
df2008_7_YANGCHEON = df2008_7_YANGCHEON.fillna(0)
df2008_7_YANGCHEON = df2008_7_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_7_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_7_YEONGDEUNGPO = df2008_7[df2008_7['측정소명'] == '영등포구']
df2008_7_YEONGDEUNGPO = df2008_7_YEONGDEUNGPO.groupby('날짜').mean()
df2008_7_YEONGDEUNGPO['PM10'] = round(df2008_7_YEONGDEUNGPO['PM10'], 2)
df2008_7_YEONGDEUNGPO = df2008_7_YEONGDEUNGPO.fillna(0)
df2008_7_YEONGDEUNGPO = df2008_7_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_7_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_7_YONGSAN = df2008_7[df2008_7['측정소명'] == '용산구']
df2008_7_YONGSAN = df2008_7_YONGSAN.groupby('날짜').mean()
df2008_7_YONGSAN['PM10'] = round(df2008_7_YONGSAN['PM10'], 2)
df2008_7_YONGSAN = df2008_7_YONGSAN.fillna(0)
df2008_7_YONGSAN = df2008_7_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_7_YONGSAN)
#print('\n')

#22 - 은평구
df2008_7_EUNPYEONG = df2008_7[df2008_7['측정소명'] == '은평구']
df2008_7_EUNPYEONG = df2008_7_EUNPYEONG.groupby('날짜').mean()
df2008_7_EUNPYEONG['PM10'] = round(df2008_7_EUNPYEONG['PM10'], 2)
df2008_7_EUNPYEONG = df2008_7_EUNPYEONG.fillna(0)
df2008_7_EUNPYEONG = df2008_7_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_7_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_7_JONGNO = df2008_7[df2008_7['측정소명'] == '종로구']
df2008_7_JONGNO = df2008_7_JONGNO.groupby('날짜').mean()
df2008_7_JONGNO['PM10'] = round(df2008_7_JONGNO['PM10'], 2)
df2008_7_JONGNO = df2008_7_JONGNO.fillna(0)
df2008_7_JONGNO = df2008_7_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_7_JONGNO)
#print('\n')

#24 - 중구
df2008_7_JUNG = df2008_7[df2008_7['측정소명'] == '중구']
df2008_7_JUNG = df2008_7_JUNG.groupby('날짜').mean()
df2008_7_JUNG['PM10'] = round(df2008_7_JUNG['PM10'], 2)
df2008_7_JUNG = df2008_7_JUNG.fillna(0)
df2008_7_JUNG = df2008_7_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_7_JUNG)
#print('\n')

#25 - 중랑구
df2008_7_JUNGNANG = df2008_7[df2008_7['측정소명'] == '중랑구']
df2008_7_JUNGNANG = df2008_7_JUNGNANG.groupby('날짜').mean()
df2008_7_JUNGNANG['PM10'] = round(df2008_7_JUNGNANG['PM10'], 2)
df2008_7_JUNGNANG = df2008_7_JUNGNANG.fillna(0)
df2008_7_JUNGNANG = df2008_7_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_7_JUNGNANG)

#======================
my2008_7 = pd.concat([df2008_7_GANGNAM, df2008_7_GANGDONG, df2008_7_GANGBUK, df2008_7_GANGSEO,
                      df2008_7_GWANAK, df2008_7_GWANGJIN, df2008_7_GURO, df2008_7_GEUMCHEON,
                      df2008_7_NOWON, df2008_7_DOBONG, df2008_7_DONGDAEMUN, df2008_7_DONGJAK,
                      df2008_7_MAPO, df2008_7_SEODAEMUN, df2008_7_SEOCHO, df2008_7_SEONGDONG,
                      df2008_7_SEONGBUK, df2008_7_SONGPA, df2008_7_YANGCHEON, df2008_7_YEONGDEUNGPO,
                      df2008_7_YONGSAN, df2008_7_EUNPYEONG, df2008_7_JONGNO, df2008_7_JUNG,
                      df2008_7_JUNGNANG], axis = 1)
#2008년 8월

#1 - 강남구
df2008_8_GANGNAM = df2008_8[df2008_8['측정소명'] == '강남구']
df2008_8_GANGNAM = df2008_8_GANGNAM.groupby('날짜').mean()
df2008_8_GANGNAM['PM10'] = round(df2008_8_GANGNAM['PM10'], 2)
df2008_8_GANGNAM = df2008_8_GANGNAM.fillna(0)
df2008_8_GANGNAM = df2008_8_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_8_GANGNAM)
#print('\n')

#2 - 강동구
df2008_8_GANGDONG = df2008_8[df2008_8['측정소명'] == '강동구']
df2008_8_GANGDONG = df2008_8_GANGDONG.groupby('날짜').mean()
df2008_8_GANGDONG['PM10'] = round(df2008_8_GANGDONG['PM10'], 2)
df2008_8_GANGDONG = df2008_8_GANGDONG.fillna(0)
df2008_8_GANGDONG = df2008_8_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_8_GANGDONG)
#print('\n')

#3 - 강북구
df2008_8_GANGBUK = df2008_8[df2008_8['측정소명'] == '강북구']
df2008_8_GANGBUK = df2008_8_GANGBUK.groupby('날짜').mean()
df2008_8_GANGBUK['PM10'] = round(df2008_8_GANGBUK['PM10'], 2)
df2008_8_GANGBUK = df2008_8_GANGBUK.fillna(0)
df2008_8_GANGBUK = df2008_8_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_8_GANGBUK)
#print('\n')

#4 - 강서구
df2008_8_GANGSEO = df2008_8[df2008_8['측정소명'] == '강서구']
df2008_8_GANGSEO = df2008_8_GANGSEO.groupby('날짜').mean()
df2008_8_GANGSEO['PM10'] = round(df2008_8_GANGSEO['PM10'], 2)
df2008_8_GANGSEO = df2008_8_GANGSEO.fillna(0)
df2008_8_GANGSEO = df2008_8_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_8_GANGSEO)
#print('\n')

#5 - 관악구
df2008_8_GWANAK = df2008_8[df2008_8['측정소명'] == '관악구']
df2008_8_GWANAK = df2008_8_GWANAK.groupby('날짜').mean()
df2008_8_GWANAK['PM10'] = round(df2008_8_GWANAK['PM10'], 2)
df2008_8_GWANAK = df2008_8_GWANAK.fillna(0)
df2008_8_GWANAK = df2008_8_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_8_GWANAK)
#print('\n')

#6 - 광진구
df2008_8_GWANGJIN = df2008_8[df2008_8['측정소명'] == '광진구']
df2008_8_GWANGJIN = df2008_8_GWANGJIN.groupby('날짜').mean()
df2008_8_GWANGJIN['PM10'] = round(df2008_8_GWANGJIN['PM10'], 2)
df2008_8_GWANGJIN = df2008_8_GWANGJIN.fillna(0)
df2008_8_GWANGJIN = df2008_8_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_8_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_8_GURO = df2008_8[df2008_8['측정소명'] == '구로구']
df2008_8_GURO = df2008_8_GURO.groupby('날짜').mean()
df2008_8_GURO['PM10'] = round(df2008_8_GURO['PM10'], 2)
df2008_8_GURO = df2008_8_GURO.fillna(0)
df2008_8_GURO = df2008_8_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_8_GURO)
#print('\n')

#8 - 금천구
df2008_8_GEUMCHEON = df2008_8[df2008_8['측정소명'] == '금천구']
df2008_8_GEUMCHEON = df2008_8_GEUMCHEON.groupby('날짜').mean()
df2008_8_GEUMCHEON['PM10'] = round(df2008_8_GEUMCHEON['PM10'], 2)
df2008_8_GEUMCHEON = df2008_8_GEUMCHEON.fillna(0)
df2008_8_GEUMCHEON = df2008_8_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_8_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_8_NOWON = df2008_8[df2008_8['측정소명'] == '노원구']
df2008_8_NOWON = df2008_8_NOWON.groupby('날짜').mean()
df2008_8_NOWON['PM10'] = round(df2008_8_NOWON['PM10'], 2)
df2008_8_NOWON = df2008_8_NOWON.fillna(0)
df2008_8_NOWON = df2008_8_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_8_NOWON)
#print('\n')

#10 - 도봉구
df2008_8_DOBONG = df2008_8[df2008_8['측정소명'] == '도봉구']
df2008_8_DOBONG = df2008_8_DOBONG.groupby('날짜').mean()
df2008_8_DOBONG['PM10'] = round(df2008_8_DOBONG['PM10'], 2)
df2008_8_DOBONG = df2008_8_DOBONG.fillna(0)
df2008_8_DOBONG = df2008_8_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_8_DOBONG)
#print('\n')

#11 - 동대문구
df2008_8_DONGDAEMUN = df2008_8[df2008_8['측정소명'] == '동대문구']
df2008_8_DONGDAEMUN = df2008_8_DONGDAEMUN.groupby('날짜').mean()
df2008_8_DONGDAEMUN['PM10'] = round(df2008_8_DONGDAEMUN['PM10'], 2)
df2008_8_DONGDAEMUN = df2008_8_DONGDAEMUN.fillna(0)
df2008_8_DONGDAEMUN = df2008_8_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_8_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_8_DONGJAK = df2008_8[df2008_8['측정소명'] == '동작구']
df2008_8_DONGJAK = df2008_8_DONGJAK.groupby('날짜').mean()
df2008_8_DONGJAK['PM10'] = round(df2008_8_DONGJAK['PM10'], 2)
df2008_8_DONGJAK = df2008_8_DONGJAK.fillna(0)
df2008_8_DONGJAK = df2008_8_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_8_DONGJAK)
#print('\n')

#13 - 마포구
df2008_8_MAPO = df2008_8[df2008_8['측정소명'] == '마포구']
df2008_8_MAPO = df2008_8_MAPO.groupby('날짜').mean()
df2008_8_MAPO['PM10'] = round(df2008_8_MAPO['PM10'], 2)
df2008_8_MAPO = df2008_8_MAPO.fillna(0)
df2008_8_MAPO = df2008_8_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_8_MAPO)
#print('\n')

#14 - 서대문구
df2008_8_SEODAEMUN = df2008_8[df2008_8['측정소명'] == '서대문구']
df2008_8_SEODAEMUN = df2008_8_SEODAEMUN.groupby('날짜').mean()
df2008_8_SEODAEMUN['PM10'] = round(df2008_8_SEODAEMUN['PM10'], 2)
df2008_8_SEODAEMUN = df2008_8_SEODAEMUN.fillna(0)
df2008_8_SEODAEMUN = df2008_8_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_8_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_8_SEOCHO = df2008_8[df2008_8['측정소명'] == '서초구']
df2008_8_SEOCHO = df2008_8_SEOCHO.groupby('날짜').mean()
df2008_8_SEOCHO['PM10'] = round(df2008_8_SEOCHO['PM10'], 2)
df2008_8_SEOCHO = df2008_8_SEOCHO.fillna(0)
df2008_8_SEOCHO = df2008_8_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_8_SEOCHO)
#print('\n')

#16 - 성동구
df2008_8_SEONGDONG = df2008_8[df2008_8['측정소명'] == '성동구']
df2008_8_SEONGDONG = df2008_8_SEONGDONG.groupby('날짜').mean()
df2008_8_SEONGDONG['PM10'] = round(df2008_8_SEONGDONG['PM10'], 2)
df2008_8_SEONGDONG = df2008_8_SEONGDONG.fillna(0)
df2008_8_SEONGDONG = df2008_8_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_8_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_8_SEONGBUK = df2008_8[df2008_8['측정소명'] == '성북구']
df2008_8_SEONGBUK = df2008_8_SEONGBUK.groupby('날짜').mean()
df2008_8_SEONGBUK['PM10'] = round(df2008_8_SEONGBUK['PM10'], 2)
df2008_8_SEONGBUK = df2008_8_SEONGBUK.fillna(0)
df2008_8_SEONGBUK = df2008_8_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_8_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_8_SONGPA = df2008_8[df2008_8['측정소명'] == '송파구']
df2008_8_SONGPA = df2008_8_SONGPA.groupby('날짜').mean()
df2008_8_SONGPA['PM10'] = round(df2008_8_SONGPA['PM10'], 2)
df2008_8_SONGPA = df2008_8_SONGPA.fillna(0)
df2008_8_SONGPA = df2008_8_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_8_SONGPA)
#print('\n')

#19 - 양천구
df2008_8_YANGCHEON = df2008_8[df2008_8['측정소명'] == '양천구']
df2008_8_YANGCHEON = df2008_8_YANGCHEON.groupby('날짜').mean()
df2008_8_YANGCHEON['PM10'] = round(df2008_8_YANGCHEON['PM10'], 2)
df2008_8_YANGCHEON = df2008_8_YANGCHEON.fillna(0)
df2008_8_YANGCHEON = df2008_8_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_8_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_8_YEONGDEUNGPO = df2008_8[df2008_8['측정소명'] == '영등포구']
df2008_8_YEONGDEUNGPO = df2008_8_YEONGDEUNGPO.groupby('날짜').mean()
df2008_8_YEONGDEUNGPO['PM10'] = round(df2008_8_YEONGDEUNGPO['PM10'], 2)
df2008_8_YEONGDEUNGPO = df2008_8_YEONGDEUNGPO.fillna(0)
df2008_8_YEONGDEUNGPO = df2008_8_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_8_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_8_YONGSAN = df2008_8[df2008_8['측정소명'] == '용산구']
df2008_8_YONGSAN = df2008_8_YONGSAN.groupby('날짜').mean()
df2008_8_YONGSAN['PM10'] = round(df2008_8_YONGSAN['PM10'], 2)
df2008_8_YONGSAN = df2008_8_YONGSAN.fillna(0)
df2008_8_YONGSAN = df2008_8_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_8_YONGSAN)
#print('\n')

#22 - 은평구
df2008_8_EUNPYEONG = df2008_8[df2008_8['측정소명'] == '은평구']
df2008_8_EUNPYEONG = df2008_8_EUNPYEONG.groupby('날짜').mean()
df2008_8_EUNPYEONG['PM10'] = round(df2008_8_EUNPYEONG['PM10'], 2)
df2008_8_EUNPYEONG = df2008_8_EUNPYEONG.fillna(0)
df2008_8_EUNPYEONG = df2008_8_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_8_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_8_JONGNO = df2008_8[df2008_8['측정소명'] == '종로구']
df2008_8_JONGNO = df2008_8_JONGNO.groupby('날짜').mean()
df2008_8_JONGNO['PM10'] = round(df2008_8_JONGNO['PM10'], 2)
df2008_8_JONGNO = df2008_8_JONGNO.fillna(0)
df2008_8_JONGNO = df2008_8_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_8_JONGNO)
#print('\n')

#24 - 중구
df2008_8_JUNG = df2008_8[df2008_8['측정소명'] == '중구']
df2008_8_JUNG = df2008_8_JUNG.groupby('날짜').mean()
df2008_8_JUNG['PM10'] = round(df2008_8_JUNG['PM10'], 2)
df2008_8_JUNG = df2008_8_JUNG.fillna(0)
df2008_8_JUNG = df2008_8_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_8_JUNG)
#print('\n')

#25 - 중랑구
df2008_8_JUNGNANG = df2008_8[df2008_8['측정소명'] == '중랑구']
df2008_8_JUNGNANG = df2008_8_JUNGNANG.groupby('날짜').mean()
df2008_8_JUNGNANG['PM10'] = round(df2008_8_JUNGNANG['PM10'], 2)
df2008_8_JUNGNANG = df2008_8_JUNGNANG.fillna(0)
df2008_8_JUNGNANG = df2008_8_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_8_JUNGNANG)

#======================
my2008_8 = pd.concat([df2008_8_GANGNAM, df2008_8_GANGDONG, df2008_8_GANGBUK, df2008_8_GANGSEO,
                      df2008_8_GWANAK, df2008_8_GWANGJIN, df2008_8_GURO, df2008_8_GEUMCHEON,
                      df2008_8_NOWON, df2008_8_DOBONG, df2008_8_DONGDAEMUN, df2008_8_DONGJAK,
                      df2008_8_MAPO, df2008_8_SEODAEMUN, df2008_8_SEOCHO, df2008_8_SEONGDONG,
                      df2008_8_SEONGBUK, df2008_8_SONGPA, df2008_8_YANGCHEON, df2008_8_YEONGDEUNGPO,
                      df2008_8_YONGSAN, df2008_8_EUNPYEONG, df2008_8_JONGNO, df2008_8_JUNG,
                      df2008_8_JUNGNANG], axis = 1)
#2008년 9월

#1 - 강남구
df2008_9_GANGNAM = df2008_9[df2008_9['측정소명'] == '강남구']
df2008_9_GANGNAM = df2008_9_GANGNAM.groupby('날짜').mean()
df2008_9_GANGNAM['PM10'] = round(df2008_9_GANGNAM['PM10'], 2)
df2008_9_GANGNAM = df2008_9_GANGNAM.fillna(0)
df2008_9_GANGNAM = df2008_9_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_9_GANGNAM)
#print('\n')

#2 - 강동구
df2008_9_GANGDONG = df2008_9[df2008_9['측정소명'] == '강동구']
df2008_9_GANGDONG = df2008_9_GANGDONG.groupby('날짜').mean()
df2008_9_GANGDONG['PM10'] = round(df2008_9_GANGDONG['PM10'], 2)
df2008_9_GANGDONG = df2008_9_GANGDONG.fillna(0)
df2008_9_GANGDONG = df2008_9_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_9_GANGDONG)
#print('\n')

#3 - 강북구
df2008_9_GANGBUK = df2008_9[df2008_9['측정소명'] == '강북구']
df2008_9_GANGBUK = df2008_9_GANGBUK.groupby('날짜').mean()
df2008_9_GANGBUK['PM10'] = round(df2008_9_GANGBUK['PM10'], 2)
df2008_9_GANGBUK = df2008_9_GANGBUK.fillna(0)
df2008_9_GANGBUK = df2008_9_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_9_GANGBUK)
#print('\n')

#4 - 강서구
df2008_9_GANGSEO = df2008_9[df2008_9['측정소명'] == '강서구']
df2008_9_GANGSEO = df2008_9_GANGSEO.groupby('날짜').mean()
df2008_9_GANGSEO['PM10'] = round(df2008_9_GANGSEO['PM10'], 2)
df2008_9_GANGSEO = df2008_9_GANGSEO.fillna(0)
df2008_9_GANGSEO = df2008_9_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_9_GANGSEO)
#print('\n')

#5 - 관악구
df2008_9_GWANAK = df2008_9[df2008_9['측정소명'] == '관악구']
df2008_9_GWANAK = df2008_9_GWANAK.groupby('날짜').mean()
df2008_9_GWANAK['PM10'] = round(df2008_9_GWANAK['PM10'], 2)
df2008_9_GWANAK = df2008_9_GWANAK.fillna(0)
df2008_9_GWANAK = df2008_9_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_9_GWANAK)
#print('\n')

#6 - 광진구
df2008_9_GWANGJIN = df2008_9[df2008_9['측정소명'] == '광진구']
df2008_9_GWANGJIN = df2008_9_GWANGJIN.groupby('날짜').mean()
df2008_9_GWANGJIN['PM10'] = round(df2008_9_GWANGJIN['PM10'], 2)
df2008_9_GWANGJIN = df2008_9_GWANGJIN.fillna(0)
df2008_9_GWANGJIN = df2008_9_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_9_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_9_GURO = df2008_9[df2008_9['측정소명'] == '구로구']
df2008_9_GURO = df2008_9_GURO.groupby('날짜').mean()
df2008_9_GURO['PM10'] = round(df2008_9_GURO['PM10'], 2)
df2008_9_GURO = df2008_9_GURO.fillna(0)
df2008_9_GURO = df2008_9_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_9_GURO)
#print('\n')

#8 - 금천구
df2008_9_GEUMCHEON = df2008_9[df2008_9['측정소명'] == '금천구']
df2008_9_GEUMCHEON = df2008_9_GEUMCHEON.groupby('날짜').mean()
df2008_9_GEUMCHEON['PM10'] = round(df2008_9_GEUMCHEON['PM10'], 2)
df2008_9_GEUMCHEON = df2008_9_GEUMCHEON.fillna(0)
df2008_9_GEUMCHEON = df2008_9_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_9_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_9_NOWON = df2008_9[df2008_9['측정소명'] == '노원구']
df2008_9_NOWON = df2008_9_NOWON.groupby('날짜').mean()
df2008_9_NOWON['PM10'] = round(df2008_9_NOWON['PM10'], 2)
df2008_9_NOWON = df2008_9_NOWON.fillna(0)
df2008_9_NOWON = df2008_9_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_9_NOWON)
#print('\n')

#10 - 도봉구
df2008_9_DOBONG = df2008_9[df2008_9['측정소명'] == '도봉구']
df2008_9_DOBONG = df2008_9_DOBONG.groupby('날짜').mean()
df2008_9_DOBONG['PM10'] = round(df2008_9_DOBONG['PM10'], 2)
df2008_9_DOBONG = df2008_9_DOBONG.fillna(0)
df2008_9_DOBONG = df2008_9_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_9_DOBONG)
#print('\n')

#11 - 동대문구
df2008_9_DONGDAEMUN = df2008_9[df2008_9['측정소명'] == '동대문구']
df2008_9_DONGDAEMUN = df2008_9_DONGDAEMUN.groupby('날짜').mean()
df2008_9_DONGDAEMUN['PM10'] = round(df2008_9_DONGDAEMUN['PM10'], 2)
df2008_9_DONGDAEMUN = df2008_9_DONGDAEMUN.fillna(0)
df2008_9_DONGDAEMUN = df2008_9_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_9_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_9_DONGJAK = df2008_9[df2008_9['측정소명'] == '동작구']
df2008_9_DONGJAK = df2008_9_DONGJAK.groupby('날짜').mean()
df2008_9_DONGJAK['PM10'] = round(df2008_9_DONGJAK['PM10'], 2)
df2008_9_DONGJAK = df2008_9_DONGJAK.fillna(0)
df2008_9_DONGJAK = df2008_9_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_9_DONGJAK)
#print('\n')

#13 - 마포구
df2008_9_MAPO = df2008_9[df2008_9['측정소명'] == '마포구']
df2008_9_MAPO = df2008_9_MAPO.groupby('날짜').mean()
df2008_9_MAPO['PM10'] = round(df2008_9_MAPO['PM10'], 2)
df2008_9_MAPO = df2008_9_MAPO.fillna(0)
df2008_9_MAPO = df2008_9_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_9_MAPO)
#print('\n')

#14 - 서대문구
df2008_9_SEODAEMUN = df2008_9[df2008_9['측정소명'] == '서대문구']
df2008_9_SEODAEMUN = df2008_9_SEODAEMUN.groupby('날짜').mean()
df2008_9_SEODAEMUN['PM10'] = round(df2008_9_SEODAEMUN['PM10'], 2)
df2008_9_SEODAEMUN = df2008_9_SEODAEMUN.fillna(0)
df2008_9_SEODAEMUN = df2008_9_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_9_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_9_SEOCHO = df2008_9[df2008_9['측정소명'] == '서초구']
df2008_9_SEOCHO = df2008_9_SEOCHO.groupby('날짜').mean()
df2008_9_SEOCHO['PM10'] = round(df2008_9_SEOCHO['PM10'], 2)
df2008_9_SEOCHO = df2008_9_SEOCHO.fillna(0)
df2008_9_SEOCHO = df2008_9_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_9_SEOCHO)
#print('\n')

#16 - 성동구
df2008_9_SEONGDONG = df2008_9[df2008_9['측정소명'] == '성동구']
df2008_9_SEONGDONG = df2008_9_SEONGDONG.groupby('날짜').mean()
df2008_9_SEONGDONG['PM10'] = round(df2008_9_SEONGDONG['PM10'], 2)
df2008_9_SEONGDONG = df2008_9_SEONGDONG.fillna(0)
df2008_9_SEONGDONG = df2008_9_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_9_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_9_SEONGBUK = df2008_9[df2008_9['측정소명'] == '성북구']
df2008_9_SEONGBUK = df2008_9_SEONGBUK.groupby('날짜').mean()
df2008_9_SEONGBUK['PM10'] = round(df2008_9_SEONGBUK['PM10'], 2)
df2008_9_SEONGBUK = df2008_9_SEONGBUK.fillna(0)
df2008_9_SEONGBUK = df2008_9_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_9_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_9_SONGPA = df2008_9[df2008_9['측정소명'] == '송파구']
df2008_9_SONGPA = df2008_9_SONGPA.groupby('날짜').mean()
df2008_9_SONGPA['PM10'] = round(df2008_9_SONGPA['PM10'], 2)
df2008_9_SONGPA = df2008_9_SONGPA.fillna(0)
df2008_9_SONGPA = df2008_9_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_9_SONGPA)
#print('\n')

#19 - 양천구
df2008_9_YANGCHEON = df2008_9[df2008_9['측정소명'] == '양천구']
df2008_9_YANGCHEON = df2008_9_YANGCHEON.groupby('날짜').mean()
df2008_9_YANGCHEON['PM10'] = round(df2008_9_YANGCHEON['PM10'], 2)
df2008_9_YANGCHEON = df2008_9_YANGCHEON.fillna(0)
df2008_9_YANGCHEON = df2008_9_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_9_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_9_YEONGDEUNGPO = df2008_9[df2008_9['측정소명'] == '영등포구']
df2008_9_YEONGDEUNGPO = df2008_9_YEONGDEUNGPO.groupby('날짜').mean()
df2008_9_YEONGDEUNGPO['PM10'] = round(df2008_9_YEONGDEUNGPO['PM10'], 2)
df2008_9_YEONGDEUNGPO = df2008_9_YEONGDEUNGPO.fillna(0)
df2008_9_YEONGDEUNGPO = df2008_9_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_9_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_9_YONGSAN = df2008_9[df2008_9['측정소명'] == '용산구']
df2008_9_YONGSAN = df2008_9_YONGSAN.groupby('날짜').mean()
df2008_9_YONGSAN['PM10'] = round(df2008_9_YONGSAN['PM10'], 2)
df2008_9_YONGSAN = df2008_9_YONGSAN.fillna(0)
df2008_9_YONGSAN = df2008_9_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_9_YONGSAN)
#print('\n')

#22 - 은평구
df2008_9_EUNPYEONG = df2008_9[df2008_9['측정소명'] == '은평구']
df2008_9_EUNPYEONG = df2008_9_EUNPYEONG.groupby('날짜').mean()
df2008_9_EUNPYEONG['PM10'] = round(df2008_9_EUNPYEONG['PM10'], 2)
df2008_9_EUNPYEONG = df2008_9_EUNPYEONG.fillna(0)
df2008_9_EUNPYEONG = df2008_9_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_9_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_9_JONGNO = df2008_9[df2008_9['측정소명'] == '종로구']
df2008_9_JONGNO = df2008_9_JONGNO.groupby('날짜').mean()
df2008_9_JONGNO['PM10'] = round(df2008_9_JONGNO['PM10'], 2)
df2008_9_JONGNO = df2008_9_JONGNO.fillna(0)
df2008_9_JONGNO = df2008_9_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_9_JONGNO)
#print('\n')

#24 - 중구
df2008_9_JUNG = df2008_9[df2008_9['측정소명'] == '중구']
df2008_9_JUNG = df2008_9_JUNG.groupby('날짜').mean()
df2008_9_JUNG['PM10'] = round(df2008_9_JUNG['PM10'], 2)
df2008_9_JUNG = df2008_9_JUNG.fillna(0)
df2008_9_JUNG = df2008_9_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_9_JUNG)
#print('\n')

#25 - 중랑구
df2008_9_JUNGNANG = df2008_9[df2008_9['측정소명'] == '중랑구']
df2008_9_JUNGNANG = df2008_9_JUNGNANG.groupby('날짜').mean()
df2008_9_JUNGNANG['PM10'] = round(df2008_9_JUNGNANG['PM10'], 2)
df2008_9_JUNGNANG = df2008_9_JUNGNANG.fillna(0)
df2008_9_JUNGNANG = df2008_9_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_9_JUNGNANG)

#======================
my2008_9 = pd.concat([df2008_9_GANGNAM, df2008_9_GANGDONG, df2008_9_GANGBUK, df2008_9_GANGSEO,
                      df2008_9_GWANAK, df2008_9_GWANGJIN, df2008_9_GURO, df2008_9_GEUMCHEON,
                      df2008_9_NOWON, df2008_9_DOBONG, df2008_9_DONGDAEMUN, df2008_9_DONGJAK,
                      df2008_9_MAPO, df2008_9_SEODAEMUN, df2008_9_SEOCHO, df2008_9_SEONGDONG,
                      df2008_9_SEONGBUK, df2008_9_SONGPA, df2008_9_YANGCHEON, df2008_9_YEONGDEUNGPO,
                      df2008_9_YONGSAN, df2008_9_EUNPYEONG, df2008_9_JONGNO, df2008_9_JUNG,
                      df2008_9_JUNGNANG], axis = 1)

#2008년 10월

#1 - 강남구
df2008_10_GANGNAM = df2008_10[df2008_10['측정소명'] == '강남구']
df2008_10_GANGNAM = df2008_10_GANGNAM.groupby('날짜').mean()
df2008_10_GANGNAM['PM10'] = round(df2008_10_GANGNAM['PM10'], 2)
df2008_10_GANGNAM = df2008_10_GANGNAM.fillna(0)
df2008_10_GANGNAM = df2008_10_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_10_GANGNAM)
#print('\n')

#2 - 강동구
df2008_10_GANGDONG = df2008_10[df2008_10['측정소명'] == '강동구']
df2008_10_GANGDONG = df2008_10_GANGDONG.groupby('날짜').mean()
df2008_10_GANGDONG['PM10'] = round(df2008_10_GANGDONG['PM10'], 2)
df2008_10_GANGDONG = df2008_10_GANGDONG.fillna(0)
df2008_10_GANGDONG = df2008_10_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_10_GANGDONG)
#print('\n')

#3 - 강북구
df2008_10_GANGBUK = df2008_10[df2008_10['측정소명'] == '강북구']
df2008_10_GANGBUK = df2008_10_GANGBUK.groupby('날짜').mean()
df2008_10_GANGBUK['PM10'] = round(df2008_10_GANGBUK['PM10'], 2)
df2008_10_GANGBUK = df2008_10_GANGBUK.fillna(0)
df2008_10_GANGBUK = df2008_10_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_10_GANGBUK)
#print('\n')

#4 - 강서구
df2008_10_GANGSEO = df2008_10[df2008_10['측정소명'] == '강서구']
df2008_10_GANGSEO = df2008_10_GANGSEO.groupby('날짜').mean()
df2008_10_GANGSEO['PM10'] = round(df2008_10_GANGSEO['PM10'], 2)
df2008_10_GANGSEO = df2008_10_GANGSEO.fillna(0)
df2008_10_GANGSEO = df2008_10_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_10_GANGSEO)
#print('\n')

#5 - 관악구
df2008_10_GWANAK = df2008_10[df2008_10['측정소명'] == '관악구']
df2008_10_GWANAK = df2008_10_GWANAK.groupby('날짜').mean()
df2008_10_GWANAK['PM10'] = round(df2008_10_GWANAK['PM10'], 2)
df2008_10_GWANAK = df2008_10_GWANAK.fillna(0)
df2008_10_GWANAK = df2008_10_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_10_GWANAK)
#print('\n')

#6 - 광진구
df2008_10_GWANGJIN = df2008_10[df2008_10['측정소명'] == '광진구']
df2008_10_GWANGJIN = df2008_10_GWANGJIN.groupby('날짜').mean()
df2008_10_GWANGJIN['PM10'] = round(df2008_10_GWANGJIN['PM10'], 2)
df2008_10_GWANGJIN = df2008_10_GWANGJIN.fillna(0)
df2008_10_GWANGJIN = df2008_10_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_10_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_10_GURO = df2008_10[df2008_10['측정소명'] == '구로구']
df2008_10_GURO = df2008_10_GURO.groupby('날짜').mean()
df2008_10_GURO['PM10'] = round(df2008_10_GURO['PM10'], 2)
df2008_10_GURO = df2008_10_GURO.fillna(0)
df2008_10_GURO = df2008_10_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_10_GURO)
#print('\n')

#8 - 금천구
df2008_10_GEUMCHEON = df2008_10[df2008_10['측정소명'] == '금천구']
df2008_10_GEUMCHEON = df2008_10_GEUMCHEON.groupby('날짜').mean()
df2008_10_GEUMCHEON['PM10'] = round(df2008_10_GEUMCHEON['PM10'], 2)
df2008_10_GEUMCHEON = df2008_10_GEUMCHEON.fillna(0)
df2008_10_GEUMCHEON = df2008_10_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_10_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_10_NOWON = df2008_10[df2008_10['측정소명'] == '노원구']
df2008_10_NOWON = df2008_10_NOWON.groupby('날짜').mean()
df2008_10_NOWON['PM10'] = round(df2008_10_NOWON['PM10'], 2)
df2008_10_NOWON = df2008_10_NOWON.fillna(0)
df2008_10_NOWON = df2008_10_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_10_NOWON)
#print('\n')

#10 - 도봉구
df2008_10_DOBONG = df2008_10[df2008_10['측정소명'] == '도봉구']
df2008_10_DOBONG = df2008_10_DOBONG.groupby('날짜').mean()
df2008_10_DOBONG['PM10'] = round(df2008_10_DOBONG['PM10'], 2)
df2008_10_DOBONG = df2008_10_DOBONG.fillna(0)
df2008_10_DOBONG = df2008_10_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_10_DOBONG)
#print('\n')

#11 - 동대문구
df2008_10_DONGDAEMUN = df2008_10[df2008_10['측정소명'] == '동대문구']
df2008_10_DONGDAEMUN = df2008_10_DONGDAEMUN.groupby('날짜').mean()
df2008_10_DONGDAEMUN['PM10'] = round(df2008_10_DONGDAEMUN['PM10'], 2)
df2008_10_DONGDAEMUN = df2008_10_DONGDAEMUN.fillna(0)
df2008_10_DONGDAEMUN = df2008_10_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_10_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_10_DONGJAK = df2008_10[df2008_10['측정소명'] == '동작구']
df2008_10_DONGJAK = df2008_10_DONGJAK.groupby('날짜').mean()
df2008_10_DONGJAK['PM10'] = round(df2008_10_DONGJAK['PM10'], 2)
df2008_10_DONGJAK = df2008_10_DONGJAK.fillna(0)
df2008_10_DONGJAK = df2008_10_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_10_DONGJAK)
#print('\n')

#13 - 마포구
df2008_10_MAPO = df2008_10[df2008_10['측정소명'] == '마포구']
df2008_10_MAPO = df2008_10_MAPO.groupby('날짜').mean()
df2008_10_MAPO['PM10'] = round(df2008_10_MAPO['PM10'], 2)
df2008_10_MAPO = df2008_10_MAPO.fillna(0)
df2008_10_MAPO = df2008_10_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_10_MAPO)
#print('\n')

#14 - 서대문구
df2008_10_SEODAEMUN = df2008_10[df2008_10['측정소명'] == '서대문구']
df2008_10_SEODAEMUN = df2008_10_SEODAEMUN.groupby('날짜').mean()
df2008_10_SEODAEMUN['PM10'] = round(df2008_10_SEODAEMUN['PM10'], 2)
df2008_10_SEODAEMUN = df2008_10_SEODAEMUN.fillna(0)
df2008_10_SEODAEMUN = df2008_10_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_10_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_10_SEOCHO = df2008_10[df2008_10['측정소명'] == '서초구']
df2008_10_SEOCHO = df2008_10_SEOCHO.groupby('날짜').mean()
df2008_10_SEOCHO['PM10'] = round(df2008_10_SEOCHO['PM10'], 2)
df2008_10_SEOCHO = df2008_10_SEOCHO.fillna(0)
df2008_10_SEOCHO = df2008_10_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_10_SEOCHO)
#print('\n')

#16 - 성동구
df2008_10_SEONGDONG = df2008_10[df2008_10['측정소명'] == '성동구']
df2008_10_SEONGDONG = df2008_10_SEONGDONG.groupby('날짜').mean()
df2008_10_SEONGDONG['PM10'] = round(df2008_10_SEONGDONG['PM10'], 2)
df2008_10_SEONGDONG = df2008_10_SEONGDONG.fillna(0)
df2008_10_SEONGDONG = df2008_10_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_10_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_10_SEONGBUK = df2008_10[df2008_10['측정소명'] == '성북구']
df2008_10_SEONGBUK = df2008_10_SEONGBUK.groupby('날짜').mean()
df2008_10_SEONGBUK['PM10'] = round(df2008_10_SEONGBUK['PM10'], 2)
df2008_10_SEONGBUK = df2008_10_SEONGBUK.fillna(0)
df2008_10_SEONGBUK = df2008_10_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_10_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_10_SONGPA = df2008_10[df2008_10['측정소명'] == '송파구']
df2008_10_SONGPA = df2008_10_SONGPA.groupby('날짜').mean()
df2008_10_SONGPA['PM10'] = round(df2008_10_SONGPA['PM10'], 2)
df2008_10_SONGPA = df2008_10_SONGPA.fillna(0)
df2008_10_SONGPA = df2008_10_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_10_SONGPA)
#print('\n')

#19 - 양천구
df2008_10_YANGCHEON = df2008_10[df2008_10['측정소명'] == '양천구']
df2008_10_YANGCHEON = df2008_10_YANGCHEON.groupby('날짜').mean()
df2008_10_YANGCHEON['PM10'] = round(df2008_10_YANGCHEON['PM10'], 2)
df2008_10_YANGCHEON = df2008_10_YANGCHEON.fillna(0)
df2008_10_YANGCHEON = df2008_10_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_10_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_10_YEONGDEUNGPO = df2008_10[df2008_10['측정소명'] == '영등포구']
df2008_10_YEONGDEUNGPO = df2008_10_YEONGDEUNGPO.groupby('날짜').mean()
df2008_10_YEONGDEUNGPO['PM10'] = round(df2008_10_YEONGDEUNGPO['PM10'], 2)
df2008_10_YEONGDEUNGPO = df2008_10_YEONGDEUNGPO.fillna(0)
df2008_10_YEONGDEUNGPO = df2008_10_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_10_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_10_YONGSAN = df2008_10[df2008_10['측정소명'] == '용산구']
df2008_10_YONGSAN = df2008_10_YONGSAN.groupby('날짜').mean()
df2008_10_YONGSAN['PM10'] = round(df2008_10_YONGSAN['PM10'], 2)
df2008_10_YONGSAN = df2008_10_YONGSAN.fillna(0)
df2008_10_YONGSAN = df2008_10_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_10_YONGSAN)
#print('\n')

#22 - 은평구
df2008_10_EUNPYEONG = df2008_10[df2008_10['측정소명'] == '은평구']
df2008_10_EUNPYEONG = df2008_10_EUNPYEONG.groupby('날짜').mean()
df2008_10_EUNPYEONG['PM10'] = round(df2008_10_EUNPYEONG['PM10'], 2)
df2008_10_EUNPYEONG = df2008_10_EUNPYEONG.fillna(0)
df2008_10_EUNPYEONG = df2008_10_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_10_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_10_JONGNO = df2008_10[df2008_10['측정소명'] == '종로구']
df2008_10_JONGNO = df2008_10_JONGNO.groupby('날짜').mean()
df2008_10_JONGNO['PM10'] = round(df2008_10_JONGNO['PM10'], 2)
df2008_10_JONGNO = df2008_10_JONGNO.fillna(0)
df2008_10_JONGNO = df2008_10_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_10_JONGNO)
#print('\n')

#24 - 중구
df2008_10_JUNG = df2008_10[df2008_10['측정소명'] == '중구']
df2008_10_JUNG = df2008_10_JUNG.groupby('날짜').mean()
df2008_10_JUNG['PM10'] = round(df2008_10_JUNG['PM10'], 2)
df2008_10_JUNG = df2008_10_JUNG.fillna(0)
df2008_10_JUNG = df2008_10_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_10_JUNG)
#print('\n')

#25 - 중랑구
df2008_10_JUNGNANG = df2008_10[df2008_10['측정소명'] == '중랑구']
df2008_10_JUNGNANG = df2008_10_JUNGNANG.groupby('날짜').mean()
df2008_10_JUNGNANG['PM10'] = round(df2008_10_JUNGNANG['PM10'], 2)
df2008_10_JUNGNANG = df2008_10_JUNGNANG.fillna(0)
df2008_10_JUNGNANG = df2008_10_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_10_JUNGNANG)

#======================
my2008_10 = pd.concat([df2008_10_GANGNAM, df2008_10_GANGDONG, df2008_10_GANGBUK, df2008_10_GANGSEO,
                      df2008_10_GWANAK, df2008_10_GWANGJIN, df2008_10_GURO, df2008_10_GEUMCHEON,
                      df2008_10_NOWON, df2008_10_DOBONG, df2008_10_DONGDAEMUN, df2008_10_DONGJAK,
                      df2008_10_MAPO, df2008_10_SEODAEMUN, df2008_10_SEOCHO, df2008_10_SEONGDONG,
                      df2008_10_SEONGBUK, df2008_10_SONGPA, df2008_10_YANGCHEON, df2008_10_YEONGDEUNGPO,
                      df2008_10_YONGSAN, df2008_10_EUNPYEONG, df2008_10_JONGNO, df2008_10_JUNG,
                      df2008_10_JUNGNANG], axis = 1)

#2008년 11월

#1 - 강남구
df2008_11_GANGNAM = df2008_11[df2008_11['측정소명'] == '강남구']
df2008_11_GANGNAM = df2008_11_GANGNAM.groupby('날짜').mean()
df2008_11_GANGNAM['PM10'] = round(df2008_11_GANGNAM['PM10'], 2)
df2008_11_GANGNAM = df2008_11_GANGNAM.fillna(0)
df2008_11_GANGNAM = df2008_11_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_11_GANGNAM)
#print('\n')

#2 - 강동구
df2008_11_GANGDONG = df2008_11[df2008_11['측정소명'] == '강동구']
df2008_11_GANGDONG = df2008_11_GANGDONG.groupby('날짜').mean()
df2008_11_GANGDONG['PM10'] = round(df2008_11_GANGDONG['PM10'], 2)
df2008_11_GANGDONG = df2008_11_GANGDONG.fillna(0)
df2008_11_GANGDONG = df2008_11_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_11_GANGDONG)
#print('\n')

#3 - 강북구
df2008_11_GANGBUK = df2008_11[df2008_11['측정소명'] == '강북구']
df2008_11_GANGBUK = df2008_11_GANGBUK.groupby('날짜').mean()
df2008_11_GANGBUK['PM10'] = round(df2008_11_GANGBUK['PM10'], 2)
df2008_11_GANGBUK = df2008_11_GANGBUK.fillna(0)
df2008_11_GANGBUK = df2008_11_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_11_GANGBUK)
#print('\n')

#4 - 강서구
df2008_11_GANGSEO = df2008_11[df2008_11['측정소명'] == '강서구']
df2008_11_GANGSEO = df2008_11_GANGSEO.groupby('날짜').mean()
df2008_11_GANGSEO['PM10'] = round(df2008_11_GANGSEO['PM10'], 2)
df2008_11_GANGSEO = df2008_11_GANGSEO.fillna(0)
df2008_11_GANGSEO = df2008_11_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_11_GANGSEO)
#print('\n')

#5 - 관악구
df2008_11_GWANAK = df2008_11[df2008_11['측정소명'] == '관악구']
df2008_11_GWANAK = df2008_11_GWANAK.groupby('날짜').mean()
df2008_11_GWANAK['PM10'] = round(df2008_11_GWANAK['PM10'], 2)
df2008_11_GWANAK = df2008_11_GWANAK.fillna(0)
df2008_11_GWANAK = df2008_11_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_11_GWANAK)
#print('\n')

#6 - 광진구
df2008_11_GWANGJIN = df2008_11[df2008_11['측정소명'] == '광진구']
df2008_11_GWANGJIN = df2008_11_GWANGJIN.groupby('날짜').mean()
df2008_11_GWANGJIN['PM10'] = round(df2008_11_GWANGJIN['PM10'], 2)
df2008_11_GWANGJIN = df2008_11_GWANGJIN.fillna(0)
df2008_11_GWANGJIN = df2008_11_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_11_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_11_GURO = df2008_11[df2008_11['측정소명'] == '구로구']
df2008_11_GURO = df2008_11_GURO.groupby('날짜').mean()
df2008_11_GURO['PM10'] = round(df2008_11_GURO['PM10'], 2)
df2008_11_GURO = df2008_11_GURO.fillna(0)
df2008_11_GURO = df2008_11_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_11_GURO)
#print('\n')

#8 - 금천구
df2008_11_GEUMCHEON = df2008_11[df2008_11['측정소명'] == '금천구']
df2008_11_GEUMCHEON = df2008_11_GEUMCHEON.groupby('날짜').mean()
df2008_11_GEUMCHEON['PM10'] = round(df2008_11_GEUMCHEON['PM10'], 2)
df2008_11_GEUMCHEON = df2008_11_GEUMCHEON.fillna(0)
df2008_11_GEUMCHEON = df2008_11_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_11_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_11_NOWON = df2008_11[df2008_11['측정소명'] == '노원구']
df2008_11_NOWON = df2008_11_NOWON.groupby('날짜').mean()
df2008_11_NOWON['PM10'] = round(df2008_11_NOWON['PM10'], 2)
df2008_11_NOWON = df2008_11_NOWON.fillna(0)
df2008_11_NOWON = df2008_11_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_11_NOWON)
#print('\n')

#10 - 도봉구
df2008_11_DOBONG = df2008_11[df2008_11['측정소명'] == '도봉구']
df2008_11_DOBONG = df2008_11_DOBONG.groupby('날짜').mean()
df2008_11_DOBONG['PM10'] = round(df2008_11_DOBONG['PM10'], 2)
df2008_11_DOBONG = df2008_11_DOBONG.fillna(0)
df2008_11_DOBONG = df2008_11_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_11_DOBONG)
#print('\n')

#11 - 동대문구
df2008_11_DONGDAEMUN = df2008_11[df2008_11['측정소명'] == '동대문구']
df2008_11_DONGDAEMUN = df2008_11_DONGDAEMUN.groupby('날짜').mean()
df2008_11_DONGDAEMUN['PM10'] = round(df2008_11_DONGDAEMUN['PM10'], 2)
df2008_11_DONGDAEMUN = df2008_11_DONGDAEMUN.fillna(0)
df2008_11_DONGDAEMUN = df2008_11_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_11_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_11_DONGJAK = df2008_11[df2008_11['측정소명'] == '동작구']
df2008_11_DONGJAK = df2008_11_DONGJAK.groupby('날짜').mean()
df2008_11_DONGJAK['PM10'] = round(df2008_11_DONGJAK['PM10'], 2)
df2008_11_DONGJAK = df2008_11_DONGJAK.fillna(0)
df2008_11_DONGJAK = df2008_11_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_11_DONGJAK)
#print('\n')

#13 - 마포구
df2008_11_MAPO = df2008_11[df2008_11['측정소명'] == '마포구']
df2008_11_MAPO = df2008_11_MAPO.groupby('날짜').mean()
df2008_11_MAPO['PM10'] = round(df2008_11_MAPO['PM10'], 2)
df2008_11_MAPO = df2008_11_MAPO.fillna(0)
df2008_11_MAPO = df2008_11_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_11_MAPO)
#print('\n')

#14 - 서대문구
df2008_11_SEODAEMUN = df2008_11[df2008_11['측정소명'] == '서대문구']
df2008_11_SEODAEMUN = df2008_11_SEODAEMUN.groupby('날짜').mean()
df2008_11_SEODAEMUN['PM10'] = round(df2008_11_SEODAEMUN['PM10'], 2)
df2008_11_SEODAEMUN = df2008_11_SEODAEMUN.fillna(0)
df2008_11_SEODAEMUN = df2008_11_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_11_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_11_SEOCHO = df2008_11[df2008_11['측정소명'] == '서초구']
df2008_11_SEOCHO = df2008_11_SEOCHO.groupby('날짜').mean()
df2008_11_SEOCHO['PM10'] = round(df2008_11_SEOCHO['PM10'], 2)
df2008_11_SEOCHO = df2008_11_SEOCHO.fillna(0)
df2008_11_SEOCHO = df2008_11_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_11_SEOCHO)
#print('\n')

#16 - 성동구
df2008_11_SEONGDONG = df2008_11[df2008_11['측정소명'] == '성동구']
df2008_11_SEONGDONG = df2008_11_SEONGDONG.groupby('날짜').mean()
df2008_11_SEONGDONG['PM10'] = round(df2008_11_SEONGDONG['PM10'], 2)
df2008_11_SEONGDONG = df2008_11_SEONGDONG.fillna(0)
df2008_11_SEONGDONG = df2008_11_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_11_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_11_SEONGBUK = df2008_11[df2008_11['측정소명'] == '성북구']
df2008_11_SEONGBUK = df2008_11_SEONGBUK.groupby('날짜').mean()
df2008_11_SEONGBUK['PM10'] = round(df2008_11_SEONGBUK['PM10'], 2)
df2008_11_SEONGBUK = df2008_11_SEONGBUK.fillna(0)
df2008_11_SEONGBUK = df2008_11_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_11_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_11_SONGPA = df2008_11[df2008_11['측정소명'] == '송파구']
df2008_11_SONGPA = df2008_11_SONGPA.groupby('날짜').mean()
df2008_11_SONGPA['PM10'] = round(df2008_11_SONGPA['PM10'], 2)
df2008_11_SONGPA = df2008_11_SONGPA.fillna(0)
df2008_11_SONGPA = df2008_11_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_11_SONGPA)
#print('\n')

#19 - 양천구
df2008_11_YANGCHEON = df2008_11[df2008_11['측정소명'] == '양천구']
df2008_11_YANGCHEON = df2008_11_YANGCHEON.groupby('날짜').mean()
df2008_11_YANGCHEON['PM10'] = round(df2008_11_YANGCHEON['PM10'], 2)
df2008_11_YANGCHEON = df2008_11_YANGCHEON.fillna(0)
df2008_11_YANGCHEON = df2008_11_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_11_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_11_YEONGDEUNGPO = df2008_11[df2008_11['측정소명'] == '영등포구']
df2008_11_YEONGDEUNGPO = df2008_11_YEONGDEUNGPO.groupby('날짜').mean()
df2008_11_YEONGDEUNGPO['PM10'] = round(df2008_11_YEONGDEUNGPO['PM10'], 2)
df2008_11_YEONGDEUNGPO = df2008_11_YEONGDEUNGPO.fillna(0)
df2008_11_YEONGDEUNGPO = df2008_11_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_11_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_11_YONGSAN = df2008_11[df2008_11['측정소명'] == '용산구']
df2008_11_YONGSAN = df2008_11_YONGSAN.groupby('날짜').mean()
df2008_11_YONGSAN['PM10'] = round(df2008_11_YONGSAN['PM10'], 2)
df2008_11_YONGSAN = df2008_11_YONGSAN.fillna(0)
df2008_11_YONGSAN = df2008_11_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_11_YONGSAN)
#print('\n')

#22 - 은평구
df2008_11_EUNPYEONG = df2008_11[df2008_11['측정소명'] == '은평구']
df2008_11_EUNPYEONG = df2008_11_EUNPYEONG.groupby('날짜').mean()
df2008_11_EUNPYEONG['PM10'] = round(df2008_11_EUNPYEONG['PM10'], 2)
df2008_11_EUNPYEONG = df2008_11_EUNPYEONG.fillna(0)
df2008_11_EUNPYEONG = df2008_11_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_11_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_11_JONGNO = df2008_11[df2008_11['측정소명'] == '종로구']
df2008_11_JONGNO = df2008_11_JONGNO.groupby('날짜').mean()
df2008_11_JONGNO['PM10'] = round(df2008_11_JONGNO['PM10'], 2)
df2008_11_JONGNO = df2008_11_JONGNO.fillna(0)
df2008_11_JONGNO = df2008_11_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_11_JONGNO)
#print('\n')

#24 - 중구
df2008_11_JUNG = df2008_11[df2008_11['측정소명'] == '중구']
df2008_11_JUNG = df2008_11_JUNG.groupby('날짜').mean()
df2008_11_JUNG['PM10'] = round(df2008_11_JUNG['PM10'], 2)
df2008_11_JUNG = df2008_11_JUNG.fillna(0)
df2008_11_JUNG = df2008_11_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_11_JUNG)
#print('\n')

#25 - 중랑구
df2008_11_JUNGNANG = df2008_11[df2008_11['측정소명'] == '중랑구']
df2008_11_JUNGNANG = df2008_11_JUNGNANG.groupby('날짜').mean()
df2008_11_JUNGNANG['PM10'] = round(df2008_11_JUNGNANG['PM10'], 2)
df2008_11_JUNGNANG = df2008_11_JUNGNANG.fillna(0)
df2008_11_JUNGNANG = df2008_11_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_11_JUNGNANG)

#======================
my2008_11 = pd.concat([df2008_11_GANGNAM, df2008_11_GANGDONG, df2008_11_GANGBUK, df2008_11_GANGSEO,
                      df2008_11_GWANAK, df2008_11_GWANGJIN, df2008_11_GURO, df2008_11_GEUMCHEON,
                      df2008_11_NOWON, df2008_11_DOBONG, df2008_11_DONGDAEMUN, df2008_11_DONGJAK,
                      df2008_11_MAPO, df2008_11_SEODAEMUN, df2008_11_SEOCHO, df2008_11_SEONGDONG,
                      df2008_11_SEONGBUK, df2008_11_SONGPA, df2008_11_YANGCHEON, df2008_11_YEONGDEUNGPO,
                      df2008_11_YONGSAN, df2008_11_EUNPYEONG, df2008_11_JONGNO, df2008_11_JUNG,
                      df2008_11_JUNGNANG], axis = 1)
#2008년 12월

#1 - 강남구
df2008_12_GANGNAM = df2008_12[df2008_12['측정소명'] == '강남구']
df2008_12_GANGNAM = df2008_12_GANGNAM.groupby('날짜').mean()
df2008_12_GANGNAM['PM10'] = round(df2008_12_GANGNAM['PM10'], 2)
df2008_12_GANGNAM = df2008_12_GANGNAM.fillna(0)
df2008_12_GANGNAM = df2008_12_GANGNAM.rename(columns={'PM10' : '강남구'})
#print(df2008_12_GANGNAM)
#print('\n')

#2 - 강동구
df2008_12_GANGDONG = df2008_12[df2008_12['측정소명'] == '강동구']
df2008_12_GANGDONG = df2008_12_GANGDONG.groupby('날짜').mean()
df2008_12_GANGDONG['PM10'] = round(df2008_12_GANGDONG['PM10'], 2)
df2008_12_GANGDONG = df2008_12_GANGDONG.fillna(0)
df2008_12_GANGDONG = df2008_12_GANGDONG.rename(columns={'PM10' : '강동구'})
#print(df2008_12_GANGDONG)
#print('\n')

#3 - 강북구
df2008_12_GANGBUK = df2008_12[df2008_12['측정소명'] == '강북구']
df2008_12_GANGBUK = df2008_12_GANGBUK.groupby('날짜').mean()
df2008_12_GANGBUK['PM10'] = round(df2008_12_GANGBUK['PM10'], 2)
df2008_12_GANGBUK = df2008_12_GANGBUK.fillna(0)
df2008_12_GANGBUK = df2008_12_GANGBUK.rename(columns={'PM10' : '강북구'})
#print(df2008_12_GANGBUK)
#print('\n')

#4 - 강서구
df2008_12_GANGSEO = df2008_12[df2008_12['측정소명'] == '강서구']
df2008_12_GANGSEO = df2008_12_GANGSEO.groupby('날짜').mean()
df2008_12_GANGSEO['PM10'] = round(df2008_12_GANGSEO['PM10'], 2)
df2008_12_GANGSEO = df2008_12_GANGSEO.fillna(0)
df2008_12_GANGSEO = df2008_12_GANGSEO.rename(columns={'PM10' : '강서구'})
#print(df2008_12_GANGSEO)
#print('\n')

#5 - 관악구
df2008_12_GWANAK = df2008_12[df2008_12['측정소명'] == '관악구']
df2008_12_GWANAK = df2008_12_GWANAK.groupby('날짜').mean()
df2008_12_GWANAK['PM10'] = round(df2008_12_GWANAK['PM10'], 2)
df2008_12_GWANAK = df2008_12_GWANAK.fillna(0)
df2008_12_GWANAK = df2008_12_GWANAK.rename(columns={'PM10' : '관악구'})
#print(df2008_12_GWANAK)
#print('\n')

#6 - 광진구
df2008_12_GWANGJIN = df2008_12[df2008_12['측정소명'] == '광진구']
df2008_12_GWANGJIN = df2008_12_GWANGJIN.groupby('날짜').mean()
df2008_12_GWANGJIN['PM10'] = round(df2008_12_GWANGJIN['PM10'], 2)
df2008_12_GWANGJIN = df2008_12_GWANGJIN.fillna(0)
df2008_12_GWANGJIN = df2008_12_GWANGJIN.rename(columns={'PM10' : '광진구'})
#print(df2008_12_GWANGJIN)
#print('\n')

#7 - 구로구
df2008_12_GURO = df2008_12[df2008_12['측정소명'] == '구로구']
df2008_12_GURO = df2008_12_GURO.groupby('날짜').mean()
df2008_12_GURO['PM10'] = round(df2008_12_GURO['PM10'], 2)
df2008_12_GURO = df2008_12_GURO.fillna(0)
df2008_12_GURO = df2008_12_GURO.rename(columns={'PM10' : '구로구'})
#print(df2008_12_GURO)
#print('\n')

#8 - 금천구
df2008_12_GEUMCHEON = df2008_12[df2008_12['측정소명'] == '금천구']
df2008_12_GEUMCHEON = df2008_12_GEUMCHEON.groupby('날짜').mean()
df2008_12_GEUMCHEON['PM10'] = round(df2008_12_GEUMCHEON['PM10'], 2)
df2008_12_GEUMCHEON = df2008_12_GEUMCHEON.fillna(0)
df2008_12_GEUMCHEON = df2008_12_GEUMCHEON.rename(columns={'PM10' : '금천구'})
#print(df2008_12_GEUMCHEON)
#print('\n')

#9 - 노원구
df2008_12_NOWON = df2008_12[df2008_12['측정소명'] == '노원구']
df2008_12_NOWON = df2008_12_NOWON.groupby('날짜').mean()
df2008_12_NOWON['PM10'] = round(df2008_12_NOWON['PM10'], 2)
df2008_12_NOWON = df2008_12_NOWON.fillna(0)
df2008_12_NOWON = df2008_12_NOWON.rename(columns={'PM10' : '노원구'})
#print(df2008_12_NOWON)
#print('\n')

#10 - 도봉구
df2008_12_DOBONG = df2008_12[df2008_12['측정소명'] == '도봉구']
df2008_12_DOBONG = df2008_12_DOBONG.groupby('날짜').mean()
df2008_12_DOBONG['PM10'] = round(df2008_12_DOBONG['PM10'], 2)
df2008_12_DOBONG = df2008_12_DOBONG.fillna(0)
df2008_12_DOBONG = df2008_12_DOBONG.rename(columns={'PM10' : '도봉구'})
#print(df2008_12_DOBONG)
#print('\n')

#11 - 동대문구
df2008_12_DONGDAEMUN = df2008_12[df2008_12['측정소명'] == '동대문구']
df2008_12_DONGDAEMUN = df2008_12_DONGDAEMUN.groupby('날짜').mean()
df2008_12_DONGDAEMUN['PM10'] = round(df2008_12_DONGDAEMUN['PM10'], 2)
df2008_12_DONGDAEMUN = df2008_12_DONGDAEMUN.fillna(0)
df2008_12_DONGDAEMUN = df2008_12_DONGDAEMUN.rename(columns={'PM10' : '동대문구'})
#print(df2008_12_DONGDAEMUN)
#print('\n')

#12 - 동작구
df2008_12_DONGJAK = df2008_12[df2008_12['측정소명'] == '동작구']
df2008_12_DONGJAK = df2008_12_DONGJAK.groupby('날짜').mean()
df2008_12_DONGJAK['PM10'] = round(df2008_12_DONGJAK['PM10'], 2)
df2008_12_DONGJAK = df2008_12_DONGJAK.fillna(0)
df2008_12_DONGJAK = df2008_12_DONGJAK.rename(columns={'PM10' : '동작구'})
#print(df2008_12_DONGJAK)
#print('\n')

#13 - 마포구
df2008_12_MAPO = df2008_12[df2008_12['측정소명'] == '마포구']
df2008_12_MAPO = df2008_12_MAPO.groupby('날짜').mean()
df2008_12_MAPO['PM10'] = round(df2008_12_MAPO['PM10'], 2)
df2008_12_MAPO = df2008_12_MAPO.fillna(0)
df2008_12_MAPO = df2008_12_MAPO.rename(columns={'PM10' : '마포구'})
#print(df2008_12_MAPO)
#print('\n')

#14 - 서대문구
df2008_12_SEODAEMUN = df2008_12[df2008_12['측정소명'] == '서대문구']
df2008_12_SEODAEMUN = df2008_12_SEODAEMUN.groupby('날짜').mean()
df2008_12_SEODAEMUN['PM10'] = round(df2008_12_SEODAEMUN['PM10'], 2)
df2008_12_SEODAEMUN = df2008_12_SEODAEMUN.fillna(0)
df2008_12_SEODAEMUN = df2008_12_SEODAEMUN.rename(columns={'PM10' : '서대문구'})
#print(df2008_12_SEODAEMUN)
#print('\n')

#15 - 서초구
df2008_12_SEOCHO = df2008_12[df2008_12['측정소명'] == '서초구']
df2008_12_SEOCHO = df2008_12_SEOCHO.groupby('날짜').mean()
df2008_12_SEOCHO['PM10'] = round(df2008_12_SEOCHO['PM10'], 2)
df2008_12_SEOCHO = df2008_12_SEOCHO.fillna(0)
df2008_12_SEOCHO = df2008_12_SEOCHO.rename(columns={'PM10' : '서초구'})
#print(df2008_12_SEOCHO)
#print('\n')

#16 - 성동구
df2008_12_SEONGDONG = df2008_12[df2008_12['측정소명'] == '성동구']
df2008_12_SEONGDONG = df2008_12_SEONGDONG.groupby('날짜').mean()
df2008_12_SEONGDONG['PM10'] = round(df2008_12_SEONGDONG['PM10'], 2)
df2008_12_SEONGDONG = df2008_12_SEONGDONG.fillna(0)
df2008_12_SEONGDONG = df2008_12_SEONGDONG.rename(columns={'PM10' : '성동구'})
#print(df2008_12_SEONGDONG)
#print('\n')

#17 - 성북구
df2008_12_SEONGBUK = df2008_12[df2008_12['측정소명'] == '성북구']
df2008_12_SEONGBUK = df2008_12_SEONGBUK.groupby('날짜').mean()
df2008_12_SEONGBUK['PM10'] = round(df2008_12_SEONGBUK['PM10'], 2)
df2008_12_SEONGBUK = df2008_12_SEONGBUK.fillna(0)
df2008_12_SEONGBUK = df2008_12_SEONGBUK.rename(columns={'PM10' : '성북구'})
#print(df2008_12_SEONGBUK)
#print('\n')

#18 - 송파구
df2008_12_SONGPA = df2008_12[df2008_12['측정소명'] == '송파구']
df2008_12_SONGPA = df2008_12_SONGPA.groupby('날짜').mean()
df2008_12_SONGPA['PM10'] = round(df2008_12_SONGPA['PM10'], 2)
df2008_12_SONGPA = df2008_12_SONGPA.fillna(0)
df2008_12_SONGPA = df2008_12_SONGPA.rename(columns={'PM10' : '송파구'})
#print(df2008_12_SONGPA)
#print('\n')

#19 - 양천구
df2008_12_YANGCHEON = df2008_12[df2008_12['측정소명'] == '양천구']
df2008_12_YANGCHEON = df2008_12_YANGCHEON.groupby('날짜').mean()
df2008_12_YANGCHEON['PM10'] = round(df2008_12_YANGCHEON['PM10'], 2)
df2008_12_YANGCHEON = df2008_12_YANGCHEON.fillna(0)
df2008_12_YANGCHEON = df2008_12_YANGCHEON.rename(columns={'PM10' : '양천구'})
#print(df2008_12_YANGCHEON)
#print('\n')

#20 - 영등포구
df2008_12_YEONGDEUNGPO = df2008_12[df2008_12['측정소명'] == '영등포구']
df2008_12_YEONGDEUNGPO = df2008_12_YEONGDEUNGPO.groupby('날짜').mean()
df2008_12_YEONGDEUNGPO['PM10'] = round(df2008_12_YEONGDEUNGPO['PM10'], 2)
df2008_12_YEONGDEUNGPO = df2008_12_YEONGDEUNGPO.fillna(0)
df2008_12_YEONGDEUNGPO = df2008_12_YEONGDEUNGPO.rename(columns={'PM10' : '영등포구'})
#print(df2008_12_YEONGDEUNGPO)
#print('\n')

#21 - 용산구
df2008_12_YONGSAN = df2008_12[df2008_12['측정소명'] == '용산구']
df2008_12_YONGSAN = df2008_12_YONGSAN.groupby('날짜').mean()
df2008_12_YONGSAN['PM10'] = round(df2008_12_YONGSAN['PM10'], 2)
df2008_12_YONGSAN = df2008_12_YONGSAN.fillna(0)
df2008_12_YONGSAN = df2008_12_YONGSAN.rename(columns={'PM10' : '용산구'})
#print(df2008_12_YONGSAN)
#print('\n')

#22 - 은평구
df2008_12_EUNPYEONG = df2008_12[df2008_12['측정소명'] == '은평구']
df2008_12_EUNPYEONG = df2008_12_EUNPYEONG.groupby('날짜').mean()
df2008_12_EUNPYEONG['PM10'] = round(df2008_12_EUNPYEONG['PM10'], 2)
df2008_12_EUNPYEONG = df2008_12_EUNPYEONG.fillna(0)
df2008_12_EUNPYEONG = df2008_12_EUNPYEONG.rename(columns={'PM10' : '은평구'})
#print(df2008_12_EUNPYEONG)
#print('\n')

#23 - 종로구
df2008_12_JONGNO = df2008_12[df2008_12['측정소명'] == '종로구']
df2008_12_JONGNO = df2008_12_JONGNO.groupby('날짜').mean()
df2008_12_JONGNO['PM10'] = round(df2008_12_JONGNO['PM10'], 2)
df2008_12_JONGNO = df2008_12_JONGNO.fillna(0)
df2008_12_JONGNO = df2008_12_JONGNO.rename(columns={'PM10' : '종로구'})
#print(df2008_12_JONGNO)
#print('\n')

#24 - 중구
df2008_12_JUNG = df2008_12[df2008_12['측정소명'] == '중구']
df2008_12_JUNG = df2008_12_JUNG.groupby('날짜').mean()
df2008_12_JUNG['PM10'] = round(df2008_12_JUNG['PM10'], 2)
df2008_12_JUNG = df2008_12_JUNG.fillna(0)
df2008_12_JUNG = df2008_12_JUNG.rename(columns={'PM10' : '중구'})
#print(df2008_12_JUNG)
#print('\n')

#25 - 중랑구
df2008_12_JUNGNANG = df2008_12[df2008_12['측정소명'] == '중랑구']
df2008_12_JUNGNANG = df2008_12_JUNGNANG.groupby('날짜').mean()
df2008_12_JUNGNANG['PM10'] = round(df2008_12_JUNGNANG['PM10'], 2)
df2008_12_JUNGNANG = df2008_12_JUNGNANG.fillna(0)
df2008_12_JUNGNANG = df2008_12_JUNGNANG.rename(columns={'PM10' : '중랑구'})
#print(df2008_12_JUNGNANG)

#======================
my2008_12 = pd.concat([df2008_12_GANGNAM, df2008_12_GANGDONG, df2008_12_GANGBUK, df2008_12_GANGSEO,
                      df2008_12_GWANAK, df2008_12_GWANGJIN, df2008_12_GURO, df2008_12_GEUMCHEON,
                      df2008_12_NOWON, df2008_12_DOBONG, df2008_12_DONGDAEMUN, df2008_12_DONGJAK,
                      df2008_12_MAPO, df2008_12_SEODAEMUN, df2008_12_SEOCHO, df2008_12_SEONGDONG,
                      df2008_12_SEONGBUK, df2008_12_SONGPA, df2008_12_YANGCHEON, df2008_12_YEONGDEUNGPO,
                      df2008_12_YONGSAN, df2008_12_EUNPYEONG, df2008_12_JONGNO, df2008_12_JUNG,
                      df2008_12_JUNGNANG], axis = 1)
my2008 = pd.concat([my2008_1, my2008_2, my2008_3, my2008_4, my2008_5, my2008_6,
                    my2008_7, my2008_8, my2008_9, my2008_10, my2008_11, my2008_12])

#파일 저장
my2008_1.to_excel('./data/output/2008_1.xlsx')
my2008_2.to_excel('./data/output/2008_2.xlsx')
my2008_3.to_excel('./data/output/2008_3.xlsx')
my2008_4.to_excel('./data/output/2008_4.xlsx')
my2008_5.to_excel('./data/output/2008_5.xlsx')
my2008_6.to_excel('./data/output/2008_6.xlsx')
my2008_7.to_excel('./data/output/2008_7.xlsx')
my2008_8.to_excel('./data/output/2008_8.xlsx')
my2008_8.to_excel('./data/output/2008_9.xlsx')
my2008_10.to_excel('./data/output/2008_10.xlsx')
my2008_11.to_excel('./data/output/2008_11.xlsx')
my2008_12.to_excel('./data/output/2008_12.xlsx')

my2008 = my2008.fillna(0)
my2008.to_excel('./data/output/2008년 미세먼지 구별 평균량.xlsx')

# %%
print(my2008)
# Out:
#             강남구    강동구    강북구    강서구    관악구    광진구    구로구    금천구    노원구  \
# 날짜
# 20080101    NaN  36.71  31.12  40.46  37.33    NaN  40.61  32.83  28.50
# 20080102    NaN  37.33  31.35  41.67  36.25    NaN  38.62  34.12  27.83
# 20080103    NaN  50.46  53.71  67.08  59.54    NaN  59.12  54.88  40.42
# 20080104    NaN  73.27  84.83  77.25  79.00    NaN  83.38  71.58  71.58
# 20080105    NaN  76.25  65.42  71.24  62.79    NaN  64.42  55.17  53.71
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 20081227  56.58  59.27  59.78  66.24  40.92  53.29  60.83  56.00  70.42
# 20081228  77.83  83.46  89.78  87.95  53.75  74.00  79.42  83.29  99.58
# 20081229  79.08  81.38  82.04  80.42  61.70  78.50  76.38  75.33  92.04
# 20081230  36.50  40.17  37.83  42.70  43.42  38.09  40.33  34.08  47.29
# 20081231  39.67  47.39  40.91  44.87  42.04  42.04  41.17  34.39  49.73
#
#             도봉구  ...    성동구    성북구    송파구    양천구   영등포구    용산구     은평구    종로구  \
# ...
